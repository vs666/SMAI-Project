# %% [markdown]
# # SatImage Dataset

# %%
from imblearn.datasets import fetch_datasets
from sklearn.model_selection import train_test_split
import numpy as np

# %%
satimage = fetch_datasets()["satimage"]
X, y = satimage.data, satimage.target

print(np.unique(y))
# Out:
# [-1  1]

# %%
from matplotlib import pyplot as plt
from numpy import where
from collections import Counter

counter = Counter(y)
print(counter)

def plot_points(counter):
    # scatter plot of examples by class label
    for label, _ in counter.items():
        row_ix = where(y == label)[0]
        plt.scatter(X[row_ix, 0], X[row_ix, 1], label=str(label))
    plt.legend()
    plt.show()
    
plot_points(counter)
# Out:
# Counter({-1: 5809, 1: 626})

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import balanced_accuracy_score
from imblearn.metrics import geometric_mean_score

def decision_tree(X, y):
    X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, random_state=0)
    tree = DecisionTreeClassifier()
    tree.fit(X_train, y_train)
    y_pred_tree = tree.predict(X_test)
    
    print("Decision tree classifier performance:")
    print(
        f"Balanced accuracy: {balanced_accuracy_score(y_test, y_pred_tree):.2f} - "
        f"Geometric mean {geometric_mean_score(y_test, y_pred_tree):.2f}"
    )

# %%
decision_tree(X, y)
# Out:
# Decision tree classifier performance:
# Balanced accuracy: 0.73 - Geometric mean 0.69

# %%
# NearMiss-1
from imblearn.under_sampling import NearMiss

undersample = NearMiss(version=1, n_neighbors=3)

# transform the dataset
X, y = undersample.fit_resample(X, y)
# summarize the new class distribution
counter = Counter(y)
print(counter)

plot_points(counter)
decision_tree(X,y)
# Out:
# Counter({-1: 626, 1: 626})
# Decision tree classifier performance:
# Balanced accuracy: 0.78 - Geometric mean 0.78

# %%
# NearMiss-2
from imblearn.under_sampling import NearMiss

X, y = satimage.data, satimage.target
undersample = NearMiss(version=2, n_neighbors=3)

# transform the dataset
X, y = undersample.fit_resample(X, y)
# summarize the new class distribution
counter = Counter(y)
print(counter)

plot_points(counter)
decision_tree(X,y)
# Out:
# Counter({-1: 626, 1: 626})
# Decision tree classifier performance:
# Balanced accuracy: 0.79 - Geometric mean 0.79

# %%
# NearMiss-3
from imblearn.under_sampling import NearMiss

X, y = satimage.data, satimage.target
undersample = NearMiss(version=3, n_neighbors=3)

# transform the dataset
X, y = undersample.fit_resample(X, y)
# summarize the new class distribution
counter = Counter(y)
print(counter)

plot_points(counter)
decision_tree(X,y)
# Out:
# Counter({-1: 626, 1: 626})
# Decision tree classifier performance:
# Balanced accuracy: 0.65 - Geometric mean 0.65

# %%
from imblearn.under_sampling import CondensedNearestNeighbour

X, y = satimage.data, satimage.target
undersample = CondensedNearestNeighbour(n_neighbors=1)
X, y = undersample.fit_resample(X, y)

counter = Counter(y)
print(counter)

plot_points(counter)
decision_tree(X,y)
# Out:
# Counter({-1: 659, 1: 626})
# Decision tree classifier performance:
# Balanced accuracy: 0.71 - Geometric mean 0.71

# %%
from imblearn.under_sampling import TomekLinks

X, y = satimage.data, satimage.target
undersample = TomekLinks()
X, y = undersample.fit_resample(X, y)

counter = Counter(y)
print(counter)

plot_points(counter)
decision_tree(X,y)
# Out:
# Counter({-1: 5770, 1: 626})
# Decision tree classifier performance:
# Balanced accuracy: 0.76 - Geometric mean 0.74

# %%
from imblearn.under_sampling import OneSidedSelection

X, y = satimage.data, satimage.target
undersample = OneSidedSelection(n_neighbors=1, n_seeds_S=200)
X, y = undersample.fit_resample(X, y)

counter = Counter(y)
print(counter)

plot_points(counter)
decision_tree(X,y)
# Out:
# Counter({-1: 1517, 1: 626})
# Decision tree classifier performance:
# Balanced accuracy: 0.71 - Geometric mean 0.71

# %% [markdown]
# # US Crime Dataset

# %%
us_crime = fetch_datasets()["us_crime"]
X, y = us_crime.data, us_crime.target

# %%
counter = Counter(y)
print(counter)

plot_points(counter)
# Out:
# Counter({-1: 1844, 1: 150})

# %%
decision_tree(X, y)
# Out:
# Decision tree classifier performance:
# Balanced accuracy: 0.67 - Geometric mean 0.61

# %%
# NearMiss-1
from imblearn.under_sampling import NearMiss

undersample = NearMiss(version=1, n_neighbors=3)

# transform the dataset
X, y = undersample.fit_resample(X, y)
# summarize the new class distribution
counter = Counter(y)
print(counter)

plot_points(counter)
decision_tree(X,y)
# Out:
# Counter({-1: 150, 1: 150})
# Decision tree classifier performance:
# Balanced accuracy: 0.71 - Geometric mean 0.71

# %%
# NearMiss-2
from imblearn.under_sampling import NearMiss

X, y = us_crime.data, us_crime.target
undersample = NearMiss(version=2, n_neighbors=3)

# transform the dataset
X, y = undersample.fit_resample(X, y)
# summarize the new class distribution
counter = Counter(y)
print(counter)

plot_points(counter)
decision_tree(X,y)
# Out:
# Counter({-1: 150, 1: 150})
# Decision tree classifier performance:
# Balanced accuracy: 0.85 - Geometric mean 0.85

# %%
# NearMiss-3
from imblearn.under_sampling import NearMiss

X, y = us_crime.data, us_crime.target
undersample = NearMiss(version=3, n_neighbors=3)

# transform the dataset
X, y = undersample.fit_resample(X, y)
# summarize the new class distribution
counter = Counter(y)
print(counter)

plot_points(counter)
decision_tree(X,y)
# Out:
# Counter({-1: 150, 1: 150})
# Decision tree classifier performance:
# Balanced accuracy: 0.57 - Geometric mean 0.55

# %%
from imblearn.under_sampling import CondensedNearestNeighbour

X, y = us_crime.data, us_crime.target
undersample = CondensedNearestNeighbour(n_neighbors=1)
X, y = undersample.fit_resample(X, y)

counter = Counter(y)
print(counter)

plot_points(counter)
decision_tree(X,y)
# Out:
# Counter({-1: 249, 1: 150})
# Decision tree classifier performance:
# Balanced accuracy: 0.67 - Geometric mean 0.66

# %%
from imblearn.under_sampling import TomekLinks

X, y = us_crime.data, us_crime.target
undersample = TomekLinks()
X, y = undersample.fit_resample(X, y)

counter = Counter(y)
print(counter)

plot_points(counter)
decision_tree(X,y)
# Out:
# Counter({-1: 1818, 1: 150})
# Decision tree classifier performance:
# Balanced accuracy: 0.71 - Geometric mean 0.68

# %%
from imblearn.under_sampling import OneSidedSelection

X, y = us_crime.data, us_crime.target
undersample = OneSidedSelection(n_neighbors=1, n_seeds_S=200)
X, y = undersample.fit_resample(X, y)

counter = Counter(y)
print(counter)

plot_points(counter)
decision_tree(X,y)
# Out:
# Counter({-1: 436, 1: 150})
# Decision tree classifier performance:
# Balanced accuracy: 0.65 - Geometric mean 0.64

# %% [markdown]
# # Oil Dataset

# %%
oil = fetch_datasets()["oil"]
X, y = oil.data, oil.target

# %%
counter = Counter(y)
print(counter)

plot_points(counter)
# Out:
# Counter({-1: 896, 1: 41})

# %%
decision_tree(X, y)
# Out:
# Decision tree classifier performance:
# Balanced accuracy: 0.63 - Geometric mean 0.54

# %%
# NearMiss-1
from imblearn.under_sampling import NearMiss

undersample = NearMiss(version=1, n_neighbors=3)

# transform the dataset
X, y = undersample.fit_resample(X, y)
# summarize the new class distribution
counter = Counter(y)
print(counter)

plot_points(counter)
decision_tree(X,y)
# Out:
# Counter({-1: 41, 1: 41})
# Decision tree classifier performance:
# Balanced accuracy: 0.85 - Geometric mean 0.85

# %%
# NearMiss-2
from imblearn.under_sampling import NearMiss

X, y = oil.data, oil.target
undersample = NearMiss(version=2, n_neighbors=3)

# transform the dataset
X, y = undersample.fit_resample(X, y)
# summarize the new class distribution
counter = Counter(y)
print(counter)

plot_points(counter)
decision_tree(X,y)
# Out:
# Counter({-1: 41, 1: 41})
# Decision tree classifier performance:
# Balanced accuracy: 0.81 - Geometric mean 0.81

# %%
# NearMiss-3
from imblearn.under_sampling import NearMiss

X, y = oil.data, oil.target
undersample = NearMiss(version=3, n_neighbors=3)

# transform the dataset
X, y = undersample.fit_resample(X, y)
# summarize the new class distribution
counter = Counter(y)
print(counter)

plot_points(counter)
decision_tree(X,y)
# Out:
# Counter({-1: 41, 1: 41})
# Decision tree classifier performance:
# Balanced accuracy: 0.76 - Geometric mean 0.76

# %%
from imblearn.under_sampling import CondensedNearestNeighbour

X, y = oil.data, oil.target
undersample = CondensedNearestNeighbour(n_neighbors=1)
X, y = undersample.fit_resample(X, y)

counter = Counter(y)
print(counter)

plot_points(counter)
decision_tree(X,y)
# Out:
# Counter({-1: 100, 1: 41})
# Decision tree classifier performance:
# Balanced accuracy: 0.89 - Geometric mean 0.89

# %%
from imblearn.under_sampling import TomekLinks

X, y = oil.data, oil.target
undersample = TomekLinks()
X, y = undersample.fit_resample(X, y)

counter = Counter(y)
print(counter)

plot_points(counter)
decision_tree(X,y)
# Out:
# Counter({-1: 873, 1: 41})
# Decision tree classifier performance:
# Balanced accuracy: 0.68 - Geometric mean 0.62

# %%
from imblearn.under_sampling import OneSidedSelection

X, y = oil.data, oil.target
undersample = OneSidedSelection(n_neighbors=1, n_seeds_S=200)
X, y = undersample.fit_resample(X, y)

counter = Counter(y)
print(counter)

plot_points(counter)
decision_tree(X,y)
# Out:
# Counter({-1: 244, 1: 41})
# Decision tree classifier performance:
# Balanced accuracy: 0.74 - Geometric mean 0.73
