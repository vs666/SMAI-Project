# %%
import os.path

from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import LinearSVC
from sklearn.calibration import CalibratedClassifierCV
from smote_variants import MLPClassifierWrapper

import smote_variants as sv

import pandas as pd
import numpy as np

import imbalanced_databases as imbd
import os, pickle, itertools

# %%
# the evaluation procedure uses a directory for caching

cache_path= os.path.join(os.path.expanduser('~'), 'smote_test')

if not os.path.exists(cache_path):
    os.makedirs(cache_path)

# %%
# instantiate classifiers
sv_classifiers= [CalibratedClassifierCV(LinearSVC(C=1.0, penalty='l1', loss= 'squared_hinge', dual= False)),
                CalibratedClassifierCV(LinearSVC(C=1.0, penalty='l2', loss= 'hinge', dual= True)),
                CalibratedClassifierCV(LinearSVC(C=1.0, penalty='l2', loss= 'squared_hinge', dual= False)),
                CalibratedClassifierCV(LinearSVC(C=10.0, penalty='l1', loss= 'squared_hinge', dual= False)),
                CalibratedClassifierCV(LinearSVC(C=10.0, penalty='l2', loss= 'hinge', dual= True)),
                CalibratedClassifierCV(LinearSVC(C=10.0, penalty='l2', loss= 'squared_hinge', dual= False))]

mlp_classifiers= []
for x in itertools.product(['relu', 'logistic'], [1.0, 0.5, 0.1]):
    mlp_classifiers.append(MLPClassifierWrapper(activation= x[0], hidden_layer_fraction= x[1]))

nn_classifiers= []
for x in itertools.product([3, 5, 7], ['uniform', 'distance'], [1, 2, 3]):
    nn_classifiers.append(KNeighborsClassifier(n_neighbors= x[0], weights= x[1], p= x[2]))

dt_classifiers= []
for x in itertools.product(['gini', 'entropy'], [None, 3, 5]):
    dt_classifiers.append(DecisionTreeClassifier(criterion= x[0], max_depth= x[1]))

classifiers= []
classifiers.extend(sv_classifiers)
classifiers.extend(mlp_classifiers)
classifiers.extend(nn_classifiers)
classifiers.extend(dt_classifiers)

# %%
datas = {}
datas['name'] = 'bupa-full'
dat = pd.read_csv('bupa-full.csv')
dat.head()
# Out:
#     Mcv  Alkphos  Sgpt  Sgot  Gammagt  Drink  output_class
# 0  85.0     92.0  45.0  27.0     31.0    0.0             0
# 1  85.0     64.0  59.0  32.0     23.0    0.0             1
# 2  91.0     78.0  34.0  24.0     36.0    0.0             1
# 3  98.0     55.0  13.0  17.0     17.0    0.0             1
# 4  88.0     67.0  21.0  11.0     11.0    0.5             0

# %%
datas['target'] = dat['output_class'].to_numpy()
dat = dat.drop('output_class', axis=1)
datas['data'] = np.array(dat.values.tolist())

# %%
# specifying the classifiers

knn_classifier= KNeighborsClassifier()
dt_classifier= DecisionTreeClassifier()
sv_classifier = CalibratedClassifierCV(LinearSVC())

# %%
samplers = [sv.SMOTE, sv.Borderline_SMOTE1, sv.Borderline_SMOTE2, sv.SMOTE_IPF]
results= sv.evaluate_oversamplers(datasets= [imbd.load_pima],
                                    samplers=samplers,
                                    classifiers=classifiers,
                                    cache_path=cache_path,
                                    n_jobs=10,
                                    max_samp_par_comb=25)
# Out:
# 2021-12-07 04:21:46,615:INFO:dataset: pima, samplings_available: True, evaluations_available: True
# 2021-12-07 04:21:46,615:INFO:doing the folding
# 2021-12-07 04:21:46,616:INFO:Folding reading from file folding_pima.pickle
# 2021-12-07 04:21:46,619:INFO:do the samplings
# 2021-12-07 04:21:46,619:INFO:create sampling objects, random_state:
# 2021-12-07 04:21:46,620:INFO:samplers: [<class 'smote_variants._smote_variants.SMOTE'>, <class 'smote_variants._smote_variants.Borderline_SMOTE1'>, <class 'smote_variants._smote_variants.Borderline_SMOTE2'>, <class 'smote_variants._smote_variants.SMOTE_IPF'>]
# 2021-12-07 04:21:46,621:INFO:[{'n_neighbors': 3, 'proportion': 0.1}, {'n_neighbors': 3, 'proportion': 0.25}, {'n_neighbors': 3, 'proportion': 0.5}, {'n_neighbors': 3, 'proportion': 0.75}, {'n_neighbors': 3, 'proportion': 1.0}, {'n_neighbors': 3, 'proportion': 1.5}, {'n_neighbors': 3, 'proportion': 2.0}, {'n_neighbors': 5, 'proportion': 0.1}, {'n_neighbors': 5, 'proportion': 0.25}, {'n_neighbors': 5, 'proportion': 0.5}, {'n_neighbors': 5, 'proportion': 0.75}, {'n_neighbors': 5, 'proportion': 1.0}, {'n_neighbors': 5, 'proportion': 1.5}, {'n_neighbors': 5, 'proportion': 2.0}, {'n_neighbors': 7, 'proportion': 0.1}, {'n_neighbors': 7, 'proportion': 0.25}, {'n_neighbors': 7, 'proportion': 0.5}, {'n_neighbors': 7, 'proportion': 0.75}, {'n_neighbors': 7, 'proportion': 1.0}, {'n_neighbors': 7, 'proportion': 1.5}, {'n_neighbors': 7, 'proportion': 2.0}]
# 2021-12-07 04:21:46,621:INFO:random_indices: [ 8 17  6 14 10 18  2 19 13 12 16 15 11  7  1  0  4  9 20  3  5]
# 2021-12-07 04:21:46,622:INFO:[{'n_neighbors': 5, 'proportion': 0.25}, {'n_neighbors': 7, 'proportion': 0.75}, {'n_neighbors': 3, 'proportion': 2.0}, {'n_neighbors': 7, 'proportion': 0.1}, {'n_neighbors': 5, 'proportion': 0.75}, {'n_neighbors': 7, 'proportion': 1.0}, {'n_neighbors': 3, 'proportion': 0.5}, {'n_neighbors': 7, 'proportion': 1.5}, {'n_neighbors': 5, 'proportion': 2.0}, {'n_neighbors': 5, 'proportion': 1.5}, {'n_neighbors': 7, 'proportion': 0.5}, {'n_neighbors': 7, 'proportion': 0.25}, {'n_neighbors': 5, 'proportion': 1.0}, {'n_neighbors': 5, 'proportion': 0.1}, {'n_neighbors': 3, 'proportion': 0.25}, {'n_neighbors': 3, 'proportion': 0.1}, {'n_neighbors': 3, 'proportion': 1.0}, {'n_neighbors': 5, 'proportion': 0.5}, {'n_neighbors': 7, 'proportion': 2.0}, {'n_neighbors': 3, 'proportion': 0.75}, {'n_neighbors': 3, 'proportion': 1.5}]
# 2021-12-07 04:21:46,622:INFO:{'n_neighbors': 5, 'proportion': 0.25, 'random_state': None}
# 2021-12-07 04:21:46,622:INFO:Sampling sampler parameter string OrderedDict([('n_neighbors', 5), ('proportion', 0.25), ('random_state', None)])
# 2021-12-07 04:21:46,623:INFO:{'n_neighbors': 7, 'proportion': 0.75, 'random_state': None}
# 2021-12-07 04:21:46,623:INFO:Sampling sampler parameter string OrderedDict([('n_neighbors', 7), ('proportion', 0.75), ('random_state', None)])
# 2021-12-07 04:21:46,624:INFO:{'n_neighbors': 3, 'proportion': 2.0, 'random_state': None}
# 2021-12-07 04:21:46,624:INFO:Sampling sampler parameter string OrderedDict([('n_neighbors', 3), ('proportion', 2.0), ('random_state', None)])
# 2021-12-07 04:21:46,625:INFO:{'n_neighbors': 7, 'proportion': 0.1, 'random_state': None}
# 2021-12-07 04:21:46,625:INFO:Sampling sampler parameter string OrderedDict([('n_neighbors', 7), ('proportion', 0.1), ('random_state', None)])
# 2021-12-07 04:21:46,626:INFO:{'n_neighbors': 5, 'proportion': 0.75, 'random_state': None}
# 2021-12-07 04:21:46,626:INFO:Sampling sampler parameter string OrderedDict([('n_neighbors', 5), ('proportion', 0.75), ('random_state', None)])
# 2021-12-07 04:21:46,628:INFO:{'n_neighbors': 7, 'proportion': 1.0, 'random_state': None}
# 2021-12-07 04:21:46,628:INFO:Sampling sampler parameter string OrderedDict([('n_neighbors', 7), ('proportion', 1.0), ('random_state', None)])
# 2021-12-07 04:21:46,629:INFO:{'n_neighbors': 3, 'proportion': 0.5, 'random_state': None}
# 2021-12-07
INFO:Sampling sampler parameter string OrderedDict([('k_neighbors', 3), ('n_neighbors', 7), ('proportion', 0.1), ('random_state', None)])
# 2021-12-07 04:21:46,684:INFO:{'k_neighbors': 5, 'n_neighbors': 5, 'proportion': 0.25, 'random_state': None}
# 2021-12-07 04:21:46,685:INFO:Sampling sampler parameter string OrderedDict([('k_neighbors', 5), ('n_neighbors', 5), ('proportion', 0.25), ('random_state', None)])
# 2021-12-07 04:21:46,685:INFO:{'k_neighbors': 3, 'n_neighbors': 7, 'proportion': 0.5, 'random_state': None}
# 2021-12-07 04:21:46,687:INFO:Sampling sampler parameter string OrderedDict([('k_neighbors', 3), ('n_neighbors', 7), ('proportion', 0.5), ('random_state', None)])
# 2021-12-07 04:21:46,687:INFO:{'k_neighbors': 3, 'n_neighbors': 7, 'proportion': 1.0, 'random_state': None}
# 2021-12-07 04:21:46,687:INFO:Sampling sampler parameter string OrderedDict([('k_neighbors', 3), ('n_neighbors', 7), ('proportion', 1.0), ('random_state', None)])
# 2021-12-07 04:21:46,688:INFO:{'k_neighbors': 5, 'n_neighbors': 7, 'proportion': 0.75, 'random_state': None}
# 2021-12-07 04:21:46,688:INFO:Sampling sampler parameter string OrderedDict([('k_neighbors', 5), ('n_neighbors', 7), ('proportion', 0.75), ('random_state', None)])
# 2021-12-07 04:21:46,689:INFO:{'k_neighbors': 3, 'n_neighbors': 3, 'proportion': 0.5, 'random_state': None}
# 2021-12-07 04:21:46,689:INFO:Sampling sampler parameter string OrderedDict([('k_neighbors', 3), ('n_neighbors', 3), ('proportion', 0.5), ('random_state', None)])
# 2021-12-07 04:21:46,689:INFO:{'k_neighbors': 3, 'n_neighbors': 7, 'proportion': 1.5, 'random_state': None}
# 2021-12-07 04:21:46,690:INFO:Sampling sampler parameter string OrderedDict([('k_neighbors', 3), ('n_neighbors', 7), ('proportion', 1.5), ('random_state', None)])
# 2021-12-07 04:21:46,690:INFO:{'k_neighbors': 3, 'n_neighbors': 3, 'proportion': 0.1, 'random_state': None}
# 2021-12-07 04:21:46,690:INFO:Sampling sampler parameter string OrderedDict([('k_neighbors', 3), ('n_neighbors', 3), ('proportion', 0.1), ('random_state', None)])
# 2021-12-07 04:21:46,691:INFO:{'k_neighbors': 3, 'n_neighbors': 3, 'proportion': 2.0, 'random_state': None}
# 2021-12-07 04:21:46,691:INFO:Sampling sampler parameter string OrderedDict([('k_neighbors', 3), ('n_neighbors', 3), ('proportion', 2.0), ('random_state', None)])
# 2021-12-07 04:21:46,692:INFO:[{'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 3, 'p': 0.01, 'proportion': 0.1, 'voting': 'majority'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 3, 'p': 0.01, 'proportion': 0.1, 'voting': 'consensus'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 3, 'p': 0.01, 'proportion': 0.25, 'voting': 'majority'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 3, 'p': 0.01, 'proportion': 0.25, 'voting': 'consensus'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 3, 'p': 0.01, 'proportion': 0.5, 'voting': 'majority'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 3, 'p': 0.01, 'proportion': 0.5, 'voting': 'consensus'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 3, 'p': 0.01, 'proportion': 0.75, 'voting': 'majority'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 3, 'p': 0.01, 'proportion': 0.75, 'voting': 'consensus'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 3, 'p': 0.01, 'proportion': 1.0, 'voting': 'majority'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 3, 'p': 0.01, 'proportion': 1.0, 'voting': 'consensus'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 3, 'p': 0.01, 'proportion': 1.5, 'voting': 'majority'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 3, 'p': 0.01, 'proportion': 1.5, 'voting': 'consensus'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 3, 'p': 0.01, 'proportion': 2.0, 'voting': 'majority'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 3, 'p': 0.01, 'proportion': 2.0, 'voting': 'consensus'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 5, 'p': 0.01, 'proportion': 0.1, 'voting': 'majority'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 5, 'p': 0.01, 'proportion': 0.1, 'voting': 'consensus'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 5, 'p': 0.01, 'proportion': 0.25, 'voting': 'majority'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 5, 'p': 0.01, 'proportion': 0.25, 'voting': 'consensus'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 5, 'p': 0.01, 'proportion': 0.5, 'voting': 'majority'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 5, 'p': 0.01, 'proportion': 0.5, 'voting': 'consensus'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 5, 'p': 0.01, 'proportion': 0.75, 'voting': 'majority'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 5, 'p': 0.01, 'proportion': 0.75, 'voting': 'consensus'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 5, 'p': 0.01, 'proportion': 1.0, 'voting': 'majority'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 5, 'p': 0.01, 'proportion': 1.0, 'voting': 'consensus'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 5, 'p': 0.01, 'proportion': 1.5, 'voting': 'majority'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 5, 'p': 0.01, 'proportion': 1.5, 'voting': 'consensus'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 5, 'p': 0 ...
# 2021-12-07 04:21:46,699:INFO:random_indices: [36 39 22 17 13 30  7 21 38 37 10 40 35 41 33  4 29 24 20  2 27 28 14  5
#  11]
# 2021-12-07 04:21:46,699:INFO:[{'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 7, 'p': 0.01, 'proportion': 1.0, 'voting': 'majority'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 7, 'p': 0.01, 'proportion': 1.5, 'voting': 'consensus'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 5, 'p': 0.01, 'proportion': 1.0, 'voting': 'majority'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 5, 'p': 0.01, 'proportion': 0.25, 'voting': 'consensus'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 3, 'p': 0.01, 'proportion': 2.0, 'voting': 'consensus'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 7, 'p': 0.01, 'proportion': 0.25, 'voting': 'majority'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 3, 'p': 0.01, 'proportion': 0.75, 'voting': 'consensus'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 5, 'p': 0.01, 'proportion': 0.75, 'voting': 'consensus'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 7, 'p': 0.01, 'proportion': 1.5, 'voting': 'majority'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 7, 'p': 0.01, 'proportion': 1.0, 'voting': 'consensus'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 3, 'p': 0.01, 'proportion': 1.5, 'voting': 'majority'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 7, 'p': 0.01, 'proportion': 2.0, 'voting': 'majority'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 7, 'p': 0.01, 'proportion': 0.75, 'voting': 'consensus'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 7, 'p': 0.01, 'proportion': 2.0, 'voting': 'consensus'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 7, 'p': 0.01, 'proportion': 0.5, 'voting': 'consensus'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 3, 'p': 0.01, 'proportion': 0.5, 'voting': 'majority'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 7, 'p': 0.01, 'proportion': 0.1, 'voting': 'consensus'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 5, 'p': 0.01, 'proportion': 1.5, 'voting': 'majority'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 5, 'p': 0.01, 'proportion': 0.75, 'voting': 'majority'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 3, 'p': 0.01, 'proportion': 0.25, 'voting': 'majority'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 5, 'p': 0.01, 'proportion': 2.0, 'voting': 'consensus'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 7, 'p': 0.01, 'proportion': 0.1, 'voting': 'majority'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 5, 'p': 0.01, 'proportion': 0.1, 'voting': 'majority'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 3, 'p': 0.01, 'proportion': 0.5, 'voting': 'consensus'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 3, 'p': 0.01, 'proportion': 1.5, 'voting': 'consensus'}]
# 2021-12-07 04:21:46,703:INFO:{'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 7, 'p': 0.01, 'proportion': 1.0, 'voting': 'majority', 'random_state': None}
# 2021-12-07 04:21:46,703:INFO:Sampling sampler parameter string OrderedDict([('classifier', DecisionTreeClassifier(random_state=2)), ('k', 3), ('n_folds', 9), ('n_neighbors', 7), ('p', 0.01), ('proportion', 1.0), ('random_state', None), ('voting', 'majority')])
# 2021-12-07 04:21:46,704:INFO:{'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 7, 'p': 0.01, 'proportion': 1.5, 'voting': 'consensus', 'random_state': None}
# 2021-12-07 04:21:46,704:INFO:Sampling sampler parameter string OrderedDict([('classifier', DecisionTreeClassifier(random_state=2)), ('k', 3), ('n_folds', 9), ('n_neighbors', 7), ('p', 0.01), ('proportion', 1.5), ('random_state', None), ('voting', 'consensus')])
# 2021-12-07 04:21:46,705:INFO:{'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 5, 'p': 0.01, 'proportion': 1.0, 'voting': 'majority', 'random_state': None}
# 2021-12-07 04:21:46,706:INFO:Sampling sampler parameter string OrderedDict([('classifier', DecisionTreeClassifier(random_state=2)), ('k', 3), ('n_folds', 9), ('n_neighbors', 5), ('p', 0.01), ('proportion', 1.0), ('random_state', None), ('voting', 'majority')])
# 2021-12-07 04:21:46,706:INFO:{'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 5, 'p': 0.01, 'proportion': 0.25, 'voting': 'consensus', 'random_state': None}
# 2021-12-07 04:21:46,707:INFO:Sampling sampler parameter string OrderedDict([('classifier', DecisionTreeClassifier(random_state=2)), ('k', 3), ('n_folds', 9), ('n_neighbors', 5), ('p', 0.01), ('proportion', 0.25), ('random_state', None), ('voting', 'consensus')])
# 2021-12-07 04:21:46,707:INFO:{'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 3, 'p': 0.01, 'proportion': 2.0, 'voting': 'consensus', 'random_state': None}
# 2021-12-07 04:21:46,708:INFO:Sampling sampler parameter string OrderedDict([('classifier', DecisionTreeClassifier(random_state=2)), ('k', 3), ('n_folds', 9), ('n_neighbors', 3), ('p', 0.01), ('proportion', 2.0), ('random_state', None), ('voting', 'consensus')])
# 2021-12-07 04:21:46,709:INFO:{'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 7, 'p': 0.01, 'proportion': 0.25, 'voting': 'majority', 'random_state': None}
# 2021-12-07 04:21:46,710:INFO:Sampling sampler parameter string OrderedDict([('classifier', DecisionTreeClassifier(random_state=2)), ('k', 3), ('n_folds', 9), ('n_neighbors', 7), ('p', 0.01), ('proportion', 0.25), ('random_state', None), ('voting', 'majority')])
# 2021-12-07 04:21:46,711:INFO:{'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 3, 'p': 0.01, 'proportion': 0.75, 'voting': 'consensus', 'random_state': None}
# 2021-12-07 04:21:46,711:INFO:Sampling sampler parameter string OrderedDict([('classifier', DecisionTreeClassifier(random_state=2)), ('k', 3), ('n_folds', 9), ('n_neighbors', 3), ('p', 0.01), ('proportion', 0.75), ('random_state', None), ('voting', 'consensus')])
# 2021-12-07 04:21:46,712:INFO:{'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 5, 'p': 0.01, 'proportion': 0.75, 'voting': 'consensus', 'random_state': None}
# 2021-12-07 04:21:46,713:INFO:Sampling sampler parameter string OrderedDict([('classifier', DecisionTreeClassifier(random_state=2)), ('k', 3), ('n_folds', 9), ('n_neighbors', 5), ('p', 0.01), ('proportion', 0.75), ('random_state', None), ('voting', 'consensus')])
# 2021-12-07 04:21:46,713:INFO:{'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 7, 'p': 0.01, 'proportion': 1.5, 'voting': 'majority', 'random_state': None}
# 2021-12-07 04:21:46,714:INFO:Sampling sampler parameter string OrderedDict([('classifier', DecisionTreeClassifier(random_state=2)), ('k', 3), ('n_folds', 9), ('n_neighbors', 7), ('p', 0.01), ('proportion', 1.5), ('random_state', None), ('voting', 'majority')])
# 2021-12-07 04:21:46,715:INFO:{'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 7, 'p': 0.01, 'proportion': 1.0, 'voting': 'consensus', 'random_state': None}
# 2021-12-07 04:21:46,715:INFO:Sampling sampler parameter string OrderedDict([('classifier', DecisionTreeClassifier(random_state=2)), ('k', 3), ('n_folds', 9), ('n_neighbors', 7), ('p', 0.01), ('proportion', 1.0), ('random_state', None), ('voting', 'consensus')])
# 2021-12-07 04:21:46,716:INFO:{'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 3, 'p': 0.01, 'proportion': 1.5, 'voting': 'majority', 'random_state': None}
# 2021-12-07 04:21:46,716:INFO:Sampling sampler parameter string OrderedDict([('classifier', DecisionTreeClassifier(random_state=2)), ('k', 3), ('n_folds', 9), ('n_neighbors', 3), ('p', 0.01), ('proportion', 1.5), ('random_state', None), ('voting', 'majority')])
# 2021-12-07 04:21:46,717:INFO:{'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 7, 'p': 0.01, 'proportion': 2.0, 'voting': 'majority', 'random_state': None}
# 2021-12-07 04:21:46,717:INFO:Sampling sampler parameter string OrderedDict([('classifier', DecisionTreeClassifier(random_state=2)), ('k', 3), ('n_folds', 9), ('n_neighbors', 7), ('p', 0.01), ('proportion', 2.0), ('random_state', None), ('voting', 'majority')])
# 2021-12-07 04:21:46,718:INFO:{'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 7, 'p': 0.01, 'proportion': 0.75, 'voting': 'consensus', 'random_state': None}
# 2021-12-07 04:21:46,718:INFO:Sampling sampler parameter string OrderedDict([('classifier', DecisionTreeClassifier(random_state=2)), ('k', 3), ('n_folds', 9), ('n_neighbors', 7), ('p', 0.01), ('proportion', 0.75), ('random_state', None), ('voting', 'consensus')])
# 2021-12-07 04:21:46,719:INFO:{'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 7, 'p': 0.01, 'proportion': 2.0, 'voting': 'consensus', 'random_state': None}
# 2021-12-07 04:21:46,719:INFO:Sampling sampler parameter string OrderedDict([('classifier', DecisionTreeClassifier(random_state=2)), ('k', 3), ('n_folds', 9), ('n_neighbors', 7), ('p', 0.01), ('proportion', 2.0), ('random_state', None), ('voting', 'consensus')])
# 2021-12-07 04:21:46,720:INFO:{'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 7, 'p': 0.01, 'proportion': 0.5, 'voting': 'consensus', 'random_state': None}
# 2021-12-07 04:21:46,720:INFO:Sampling sampler parameter string OrderedDict([('classifier', DecisionTreeClassifier(random_state=2)), ('k', 3), ('n_folds', 9), ('n_neighbors', 7), ('p', 0.01), ('proportion', 0.5), ('random_state', None), ('voting', 'consensus')])
# 2021-12-07 04:21:46,721:INFO:{'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 3, 'p': 0.01, 'proportion': 0.5, 'voting': 'majority', 'random_state': None}
# 2021-12-07 04:21:46,721:INFO:Sampling sampler parameter string OrderedDict([('classifier', DecisionTreeClassifier(random_state=2)), ('k', 3), ('n_folds', 9), ('n_neighbors', 3), ('p', 0.01), ('proportion', 0.5), ('random_state', None), ('voting', 'majority')])
# 2021-12-07 04:21:46,722:INFO:{'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 7, 'p': 0.01, 'proportion': 0.1, 'voting': 'consensus', 'random_state': None}
# 2021-12-07 04:21:46,724:INFO:Sampling sampler parameter string OrderedDict([('classifier', DecisionTreeClassifier(random_state=2)), ('k', 3), ('n_folds', 9), ('n_neighbors', 7), ('p', 0.01), ('proportion', 0.1), ('random_state', None), ('voting', 'consensus')])
# 2021-12-07 04:21:46,724:INFO:{'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 5, 'p': 0.01, 'proportion':
INFO:Evaluation do the evaluation pima Borderline_SMOTE1 DecisionTreeClassifier
# 2021-12-07 04:22:25,883:INFO:Evaluation do the evaluation pima Borderline_SMOTE1 DecisionTreeClassifier
# 2021-12-07 04:22:25,886:INFO:Evaluation do the evaluation pima Borderline_SMOTE1 DecisionTreeClassifier
# 2021-12-07 04:22:25,932:INFO:Evaluation do the evaluation pima Borderline_SMOTE1 DecisionTreeClassifier
# 2021-12-07 04:22:25,943:INFO:Evaluation do the evaluation pima Borderline_SMOTE1 DecisionTreeClassifier
# 2021-12-07 04:22:25,997:INFO:Evaluation dumping to file eval_pima_Borderline_SMOTE1_0d4bcf37a3dd38dcfb1608bc2b39bddb.pickle
# 2021-12-07 04:22:26,019:INFO:Evaluation do the evaluation pima Borderline_SMOTE1 DecisionTreeClassifier
# 2021-12-07 04:22:26,065:INFO:Evaluation do the evaluation pima Borderline_SMOTE1 DecisionTreeClassifier
# 2021-12-07 04:22:26,119:INFO:Evaluation dumping to file eval_pima_Borderline_SMOTE1_4820fcb785b5a0f5f636a4fc4b40e54b.pickle
# 2021-12-07 04:22:26,125:INFO:concatenating the results
# 2021-12-07 04:22:26,307:INFO:aggregating the results

# %%
highest_auc_score= results['auc'].idxmax()
print(highest_auc_score)
# Out:
# 15

# %%
print(results.columns)
print("------------------------")
print(results)
# Out:
# Index(['db_name', 'classifier', 'sampler', 'auc', 'auc_mean', 'auc_std',
#        'brier', 'acc', 'f1', 'p_top20', 'gacc', 'runtime', 'db_size',
#        'db_n_attr', 'imbalanced_ratio', 'sampler_categories',
#        'classifier_parameters_auc', 'classifier_parameters_acc',
#        'classifier_parameters_gacc', 'classifier_parameters_f1',
#        'classifier_parameters_p_top20', 'classifier_parameters_brier',
#        'sampler_parameters_auc', 'sampler_parameters_acc',
#        'sampler_parameters_gacc', 'sampler_parameters_f1',
#        'sampler_parameters_p_top20', 'sampler_parameters_brier'],
#       dtype='object')
# ------------------------
#    db_name              classifier            sampler       auc  auc_mean  \
# 0     pima  CalibratedClassifierCV  Borderline_SMOTE1  0.831257  0.832479
# 1     pima  CalibratedClassifierCV  Borderline_SMOTE2  0.831399  0.832364
# 2     pima  CalibratedClassifierCV              SMOTE  0.831363  0.832332
# 3     pima  CalibratedClassifierCV          SMOTE_IPF  0.831321  0.832461
# 4     pima  DecisionTreeClassifier  Borderline_SMOTE1  0.798875  0.797119
# 5     pima  DecisionTreeClassifier  Borderline_SMOTE2  0.800572  0.799496
# 6     pima  DecisionTreeClassifier              SMOTE  0.800692  0.795424
# 7     pima  DecisionTreeClassifier          SMOTE_IPF  0.797611  0.795550
# 8     pima    KNeighborsClassifier  Borderline_SMOTE1  0.786886  0.787566
# 9     pima    KNeighborsClassifier  Borderline_SMOTE2  0.787107  0.786936
# 10    pima    KNeighborsClassifier              SMOTE  0.790035  0.790263
# 11    pima    KNeighborsClassifier          SMOTE_IPF  0.791527  0.791664
# 12    pima    MLPClassifierWrapper  Borderline_SMOTE1  0.831400  0.833934
# 13    pima    MLPClassifierWrapper  Borderline_SMOTE2  0.832067  0.833686
# 14    pima    MLPClassifierWrapper              SMOTE  0.832194  0.832139
# 15    pima    MLPClassifierWrapper          SMOTE_IPF  0.833852  0.835265
#
#      auc_std     brier       acc        f1   p_top20  ...  \
# 0   0.028657  0.157121  0.773872  0.673763  0.791304  ...
# 1   0.028446  0.157061  0.775608  0.677892  0.797826  ...
# 2   0.028001  0.157102  0.773872  0.679633  0.797826  ...
# 3   0.027817  0.157008  0.773438  0.680279  0.791304  ...
# 4   0.032364  0.170367  0.748698  0.661662  0.728261  ...
# 5   0.028095  0.171158  0.750434  0.655480  0.723913  ...
# 6   0.029477  0.171585  0.750000  0.664910  0.730435  ...
# 7   0.035590  0.172354  0.751736  0.659490  0.730435  ...
# 8   0.025004  0.176782  0.744358  0.657961  0.700000  ...
# 9   0.024824  0.176490  0.744792  0.653445  0.695652  ...
# 10  0.021369  0.176738  0.742622  0.664203  0.704348  ...
# 11  0.026136  0.176118  0.744358  0.662434  0.708696  ...
# 12  0.025641  0.158107  0.766059  0.679775  0.778261  ...
# 13  0.023095  0.157590  0.770399  0.679452  0.789130  ...
# 14  0.021534  0.157397  0.772569  0.679561  0.778261  ...
# 15  0.028090  0.158608  0.766927  0.681466  0.782609  ...
#
#                            classifier_parameters_gacc  \
# 0   {'base_estimator__C': 10.0, 'base_estimator__c...
# 1   {'base_estimator__C': 1.0, 'base_estimator__cl...
# 2   {'base_estimator__C': 10.0, 'base_estimator__c...
# 3   {'base_estimator__C': 1.0, 'base_estimator__cl...
# 4   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...
# 5   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...
# 6   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...
# 7   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...
# 8   {'algorithm': 'auto', 'leaf_size': 30, 'metric...
# 9   {'algorithm': 'auto', 'leaf_size': 30, 'metric...
# 10  {'algorithm': 'auto', 'leaf_size': 30, 'metric...
# 11  {'algorithm': 'auto', 'leaf_size': 30, 'metric...
# 12  {'activation': 'relu', 'hidden_layer_fraction'...
# 13  {'activation': 'relu', 'hidden_layer_fraction'...
# 14  {'activation': 'relu', 'hidden_layer_fraction'...
# 15  {'activation': 'relu', 'hidden_layer_fraction'...
#
#                              classifier_parameters_f1  \
# 0   {'base_estimator__C': 1.0, 'base_estimator__cl...
# 1   {'base_estimator__C': 10.0, 'base_estimator__c...
# 2   {'base_estimator__C': 10.0, 'base_estimator__c...
# 3   {'base_estimator__C': 1.0, 'base_estimator__cl...
# 4   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...
# 5   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...
# 6   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...
# 7   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...
# 8   {'algorithm': 'auto', 'leaf_size': 30, 'metric...
# 9   {'algorithm': 'auto', 'leaf_size': 30, 'metric...
# 10  {'algorithm': 'auto', 'leaf_size': 30, 'metric...
# 11  {'algorithm': 'auto', 'leaf_size': 30, 'metric...
# 12  {'activation': 'relu', 'hidden_layer_fraction'...
# 13  {'activation': 'relu', 'hidden_layer_fraction'...
# 14  {'activation': 'relu', 'hidden_layer_fraction'...
# 15  {'activation': 'relu', 'hidden_layer_fraction'...
#
#                         classifier_parameters_p_top20  \
# 0   {'base_estimator__C': 1.0, 'base_estimator__cl...
# 1   {'base_estimator__C': 10.0, 'base_estimator__c...
# 2   {'base_estimator__C': 10.0, 'base_estimator__c...
# 3   {'base_estimator__C': 10.0, 'base_estimator__c...
# 4   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...
# 5   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...
# 6   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...
# 7   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...
# 8   {'algorithm': 'auto', 'leaf_size': 30, 'metric...
# 9   {'algorithm': 'auto', 'leaf_size': 30, 'metric...
# 10  {'algorithm': 'auto', 'leaf_size': 30, 'metric...
# 11  {'algorithm': 'auto', 'leaf_size': 30, 'metric...
# 12  {'activation': 'relu', 'hidden_layer_fraction'...
# 13  {'activation': 'logistic', 'hidden_layer_fract...
# 14  {'activation': 'relu', 'hidden_layer_fraction'...
# 15  {'activation': 'relu', 'hidden_layer_fraction'...
#
#                           classifier_parameters_brier  \
# 0   {'base_estimator__C': 10.0, 'base_estimator__c...
# 1   {'base_estimator__C': 10.0, 'base_estimator__c...
# 2   {'base_estimator__C': 10.0, 'base_estimator__c...
# 3   {'base_estimator__C': 10.0, 'base_estimator__c...
# 4   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...
# 5   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...
# 6   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...
# 7   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...
# 8   {'algorithm': 'auto', 'leaf_size': 30, 'metric...
# 9   {'algorithm': 'auto', 'leaf_size': 30, 'metric...
# 10  {'algorithm': 'auto', 'leaf_size': 30, 'metric...
# 11  {'algorithm': 'auto', 'leaf_size': 30, 'metric...
# 12  {'activation': 'logistic', 'hidden_layer_fract...
# 13  {'activation': 'logistic', 'hidden_layer_fract...
# 14  {'activation': 'logistic', 'hidden_layer_fract...
# 15  {'activation': 'logistic', 'hidden_layer_fract...
#
#                                sampler_parameters_auc  \
# 0   {'k_neighbors': 3, 'n_neighbors': 5, 'proporti...
# 1   {'k_neighbors': 3, 'n_neighbors': 7, 'proporti...
# 2   {'n_neighbors': 3, 'proportion': 0.1, 'random_...
# 3   {'classifier': DecisionTreeClassifier(random_s...
# 4   {'k_neighbors': 5, 'n_neighbors': 3, 'proporti...
# 5   {'k_neighbors': 3, 'n_neighbors': 7, 'proporti...
# 6   {'n_neighbors': 5, 'proportion': 0.5, 'random_...
# 7   {'classifier': DecisionTreeClassifier(random_s...
# 8   {'k_neighbors': 5, 'n_neighbors': 5, 'proporti...
# 9   {'k_neighbors': 7, 'n_neighbors': 7, 'proporti...
# 10  {'n_neighbors': 7, 'proportion': 0.25, 'random...
# 11  {'classifier': DecisionTreeClassifier(random_s...
# 12  {'k_neighbors': 7, 'n_neighbors': 7, 'proporti...
# 13  {'k_neighbors': 5, 'n_neighbors': 5, 'proporti...
# 14  {'n_neighbors': 7, 'proportion': 0.25, 'random...
# 15  {'classifier': DecisionTreeClassifier(random_s...
#
#                                sampler_parameters_acc  \
# 0   {'k_neighbors': 3, 'n_neighbors': 7, 'proporti...
# 1   {'k_neighbors': 3, 'n_neighbors': 7, 'proporti...
# 2   {'n_neighbors': 5, 'proportion': 0.1, 'random_...
# 3   {'classifier': DecisionTreeClassifier(random_s...
# 4   {'k_neighbors': 5, 'n_neighbors': 3, 'proporti...
# 5   {'k_neighbors': 3, 'n_neighbors': 7, 'proporti...
# 6   {'n_neighbors': 5, 'proportion': 0.1, 'random_...
# 7   {'classifier': DecisionTreeClassifier(random_s...
# 8   {'k_neighbors': 5, 'n_neighbors': 5, 'proporti...
# 9   {'k_neighbors': 7, 'n_neighbors': 7, 'proporti...
# 10  {'n_neighbors': 5, 'proportion': 0.1, 'random_...
# 11  {'classifier': DecisionTreeClassifier(random_s...
# 12  {'k_neighbors': 5, 'n_neighbors': 3, 'proporti...
# 13  {'k_neighbors': 3, 'n_neighbors': 3, 'proporti...
# 14  {'n_neighbors': 5, 'proportion': 0.25, 'random...
# 15  {'classifier': DecisionTreeClassifier(random_s...
#
#                               sampler_parameters_gacc  \
# 0   {'k_neighbors': 5, 'n_neighbors': 7, 'proporti...
# 1   {'k_neighbors': 7, 'n_neighbors': 3, 'proporti...
# 2   {'n_neighbors': 7, 'proportion': 1.5, 'random_...
# 3   {'classifier': DecisionTreeClassifier(random_s...
# 4   {'k_neighbors': 3, 'n_neighbors': 5, 'proporti...
# 5   {'k_neighbors': 7, 'n_neighbors': 3, 'proporti...
# 6   {'n_neighbors': 3, 'proportion': 1.5, 'random_...
# 7   {'classifier': DecisionTreeClassifier(random_s...
# 8   {'k_neighbors': 5, 'n_neighbors': 3, 'proporti...
# 9   {'k_neighbors': 7, 'n_neighbors': 3, 'proporti...
# 10  {'n_neighbors': 5, 'proportion': 1.5, 'random_...
# 11  {'classifier': DecisionTreeClassifier(random_s...
# 12  {'k_neighbors': 7, 'n_neighbors': 5, 'proporti...
# 13  {'k_neighbors': 7, 'n_neighbors': 3, 'proporti...
# 14  {'n_neighbors': 3, 'proportion': 1.0, 'random_...
# 15  {'classifier': DecisionTreeClassifier(random_s...
#
#                                 sampler_parameters_f1  \
# 0   {'k_neighbors': 7, 'n_neighbors': 3, 'proporti...
# 1   {'k_neighbors': 3, 'n_neighbors': 7, 'proporti...
# 2   {'n_neighbors': 7, 'proportion': 1.5, 'random_...
# 3   {'classifier': DecisionTreeClassifier(random_s...
# 4   {'k_neighbors': 3, 'n_neighbors': 5, 'proporti...
# 5   {'k_neighbors': 3, 'n_neighbors': 3, 'proporti...
# 6   {'n_neighbors': 3, 'proportion': 1.5, 'random_...
# 7   {'classifier': DecisionTreeClassifier(random_s...
# 8   {'k_neighbors': 7, 'n_neighbors': 3, 'proporti...
# 9   {'k_neighbors': 3, 'n_neighbors': 3, 'proporti...
# 10  {'n_neighbors': 5, 'proportion': 1.5, 'random_...
# 11  {'classifier': DecisionTreeClassifier(random_s...
# 12  {'k_neighbors': 7, 'n_neighbors': 5, 'proporti...
# 13  {'k_neighbors': 7, 'n_neighbors': 3, 'proporti...
# 14  {'n_neighbors': 7, 'proportion': 2.0, 'random_...
# 15  {'classifier': DecisionTreeClassifier(random_s...
#
#                            sampler_parameters_p_top20  \
# 0   {'k_neighbors': 3, 'n_neighbors': 3, 'proporti...
# 1   {'k_neighbors': 3, 'n_neighbors': 3, 'proporti...
# 2   {'n_neighbors': 7, 'proportion': 0.75, 'random...
# 3   {'classifier': DecisionTreeClassifier(random_s...
# 4   {'k_neighbors': 7, 'n_neighbors': 5, 'proporti...
# 5   {'k_neighbors': 3, 'n_neighbors': 3, 'proporti...
# 6   {'n_neighbors': 7, 'proportion': 0.5, 'random_...
# 7   {'classifier': DecisionTreeClassifier(random_s...
# 8   {'k_neighbors': 5, 'n_neighbors': 3, 'proporti...
# 9   {'k_neighbors': 7, 'n_neighbors': 7, 'proporti...
# 10  {'n_neighbors': 7, 'proportion': 0.25, 'random...
# 11  {'classifier': DecisionTreeClassifier(random_s...
# 12  {'k_neighbors': 7, 'n_neighbors': 7, 'proporti...
# 13  {'k_neighbors': 5, 'n_neighbors': 5, 'proporti...
# 14  {'n_neighbors': 7, 'proportion': 1.0, 'random_...
# 15  {'classifier': DecisionTreeClassifier(random_s...
#
#                              sampler_parameters_brier
# 0   {'k_neighbors': 7, 'n_neighbors': 7, 'proporti...
# 1   {'k_neighbors': 7, 'n_neighbors': 7, 'proporti...
# 2   {'n_neighbors': 3, 'proportion': 2.0, 'random_...
# 3   {'classifier': DecisionTreeClassifier(random_s...
# 4   {'k_neighbors': 3, 'n_neighbors': 7, 'proporti...
# 5   {'k_neighbors': 5, 'n_neighbors': 5, 'proporti...
# 6   {'n_neighbors': 3, 'proportion': 2.0, 'random_...
# 7   {'classifier': DecisionTreeClassifier(random_s...
# 8   {'k_neighbors': 3, 'n_neighbors': 7, 'proporti...
# 9   {'k_neighbors': 3, 'n_neighbors': 7, 'proporti...
# 10  {'n_neighbors': 7, 'proportion': 2.0, 'random_...
# 11  {'classifier': DecisionTreeClassifier(random_s...
# 12  {'k_neighbors': 3, 'n_neighbors': 3, 'proporti...
# 13  {'k_neighbors': 3, 'n_neighbors': 7, 'proporti...
# 14  {'n_neighbors': 7, 'proportion': 0.5, 'random_...
# 15  {'classifier': DecisionTreeClassifier(random_s...
#
# [16 rows x 28 columns]

# %%
print(results[['db_name', 'classifier', 'sampler', 'auc']].to_html('pima.html'))
# Out:
# None
