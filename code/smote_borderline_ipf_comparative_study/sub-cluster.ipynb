# %%
import os.path

from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import LinearSVC
from sklearn.calibration import CalibratedClassifierCV
from smote_variants import MLPClassifierWrapper

import smote_variants as sv

import pandas as pd
import numpy as np

import imbalanced_databases as imbd
import os, pickle, itertools

# %%
# the evaluation procedure uses a directory for caching

cache_path= os.path.join(os.path.expanduser('~'), 'smote_test')

if not os.path.exists(cache_path):
    os.makedirs(cache_path)

# %%
# instantiate classifiers
sv_classifiers= [CalibratedClassifierCV(LinearSVC(C=1.0, penalty='l1', loss= 'squared_hinge', dual= False)),
                CalibratedClassifierCV(LinearSVC(C=1.0, penalty='l2', loss= 'hinge', dual= True)),
                CalibratedClassifierCV(LinearSVC(C=1.0, penalty='l2', loss= 'squared_hinge', dual= False)),
                CalibratedClassifierCV(LinearSVC(C=10.0, penalty='l1', loss= 'squared_hinge', dual= False)),
                CalibratedClassifierCV(LinearSVC(C=10.0, penalty='l2', loss= 'hinge', dual= True)),
                CalibratedClassifierCV(LinearSVC(C=10.0, penalty='l2', loss= 'squared_hinge', dual= False))]

mlp_classifiers= []
for x in itertools.product(['relu', 'logistic'], [1.0, 0.5, 0.1]):
    mlp_classifiers.append(MLPClassifierWrapper(activation= x[0], hidden_layer_fraction= x[1]))

nn_classifiers= []
for x in itertools.product([3, 5, 7], ['uniform', 'distance'], [1, 2, 3]):
    nn_classifiers.append(KNeighborsClassifier(n_neighbors= x[0], weights= x[1], p= x[2]))

dt_classifiers= []
for x in itertools.product(['gini', 'entropy'], [None, 3, 5]):
    dt_classifiers.append(DecisionTreeClassifier(criterion= x[0], max_depth= x[1]))

classifiers= []
classifiers.extend(sv_classifiers)
classifiers.extend(mlp_classifiers)
classifiers.extend(nn_classifiers)
classifiers.extend(dt_classifiers)

# %%
datas = {}
datas['name'] = '03subcl5-800-7-30-BI-full'
dat = pd.read_csv('03subcl5-800-7-30-BI-full.csv')
dat.head()
# Out:
#     dim1   dim2  output_class
# 0  223.0  763.0             0
# 1  187.0   34.0             0
# 2  204.0   89.0             0
# 3  196.0  -81.0             0
# 4  201.0  733.0             0

# %%
datas['target'] = dat['output_class'].to_numpy()
dat = dat.drop('output_class', axis=1)
datas['data'] = np.array(dat.values.tolist())

# %%
# specifying the classifiers

knn_classifier= KNeighborsClassifier()
dt_classifier= DecisionTreeClassifier()
sv_classifier = CalibratedClassifierCV(LinearSVC())

# %%
samplers = [sv.SMOTE, sv.Borderline_SMOTE1, sv.Borderline_SMOTE2, sv.SMOTE_IPF]
results= sv.evaluate_oversamplers(datasets= [datas],
                                    samplers= samplers,
                                    classifiers= classifiers,
                                    cache_path= cache_path,
                                    n_jobs= 10,
                                    max_samp_par_comb=25)
# Out:
# 2021-12-07 03:34:51,307:INFO:dataset: 03subcl5-800-7-30-BI-full, samplings_available: True, evaluations_available: True
# 2021-12-07 03:34:51,308:INFO:doing the folding
# 2021-12-07 03:34:51,308:INFO:Folding reading from file folding_03subcl5-800-7-30-BI-full.pickle
# 2021-12-07 03:34:51,310:INFO:do the samplings
# 2021-12-07 03:34:51,310:INFO:create sampling objects, random_state:
# 2021-12-07 03:34:51,311:INFO:samplers: [<class 'smote_variants._smote_variants.SMOTE'>, <class 'smote_variants._smote_variants.Borderline_SMOTE1'>, <class 'smote_variants._smote_variants.Borderline_SMOTE2'>, <class 'smote_variants._smote_variants.SMOTE_IPF'>]
# 2021-12-07 03:34:51,311:INFO:[{'n_neighbors': 3, 'proportion': 0.1}, {'n_neighbors': 3, 'proportion': 0.25}, {'n_neighbors': 3, 'proportion': 0.5}, {'n_neighbors': 3, 'proportion': 0.75}, {'n_neighbors': 3, 'proportion': 1.0}, {'n_neighbors': 3, 'proportion': 1.5}, {'n_neighbors': 3, 'proportion': 2.0}, {'n_neighbors': 5, 'proportion': 0.1}, {'n_neighbors': 5, 'proportion': 0.25}, {'n_neighbors': 5, 'proportion': 0.5}, {'n_neighbors': 5, 'proportion': 0.75}, {'n_neighbors': 5, 'proportion': 1.0}, {'n_neighbors': 5, 'proportion': 1.5}, {'n_neighbors': 5, 'proportion': 2.0}, {'n_neighbors': 7, 'proportion': 0.1}, {'n_neighbors': 7, 'proportion': 0.25}, {'n_neighbors': 7, 'proportion': 0.5}, {'n_neighbors': 7, 'proportion': 0.75}, {'n_neighbors': 7, 'proportion': 1.0}, {'n_neighbors': 7, 'proportion': 1.5}, {'n_neighbors': 7, 'proportion': 2.0}]
# 2021-12-07 03:34:51,312:INFO:random_indices: [11  9 16  0 18  5  3 20  2 12 17 13  6 10  4 14 15  7  1  8 19]
# 2021-12-07 03:34:51,313:INFO:[{'n_neighbors': 5, 'proportion': 1.0}, {'n_neighbors': 5, 'proportion': 0.5}, {'n_neighbors': 7, 'proportion': 0.5}, {'n_neighbors': 3, 'proportion': 0.1}, {'n_neighbors': 7, 'proportion': 1.0}, {'n_neighbors': 3, 'proportion': 1.5}, {'n_neighbors': 3, 'proportion': 0.75}, {'n_neighbors': 7, 'proportion': 2.0}, {'n_neighbors': 3, 'proportion': 0.5}, {'n_neighbors': 5, 'proportion': 1.5}, {'n_neighbors': 7, 'proportion': 0.75}, {'n_neighbors': 5, 'proportion': 2.0}, {'n_neighbors': 3, 'proportion': 2.0}, {'n_neighbors': 5, 'proportion': 0.75}, {'n_neighbors': 3, 'proportion': 1.0}, {'n_neighbors': 7, 'proportion': 0.1}, {'n_neighbors': 7, 'proportion': 0.25}, {'n_neighbors': 5, 'proportion': 0.1}, {'n_neighbors': 3, 'proportion': 0.25}, {'n_neighbors': 5, 'proportion': 0.25}, {'n_neighbors': 7, 'proportion': 1.5}]
# 2021-12-07 03:34:51,313:INFO:{'n_neighbors': 5, 'proportion': 1.0, 'random_state': None}
# 2021-12-07 03:34:51,313:INFO:Sampling sampler parameter string OrderedDict([('n_neighbors', 5), ('proportion', 1.0), ('random_state', None)])
# 2021-12-07 03:34:51,314:INFO:{'n_neighbors': 5, 'proportion': 0.5, 'random_state': None}
# 2021-12-07 03:34:51,314:INFO:Sampling sampler parameter string OrderedDict([('n_neighbors', 5), ('proportion', 0.5), ('random_state', None)])
# 2021-12-07 03:34:51,315:INFO:{'n_neighbors': 7, 'proportion': 0.5, 'random_state': None}
# 2021-12-07 03:34:51,315:INFO:Sampling sampler parameter string OrderedDict([('n_neighbors', 7), ('proportion', 0.5), ('random_state', None)])
# 2021-12-07 03:34:51,315:INFO:{'n_neighbors': 3, 'proportion': 0.1, 'random_state': None}
# 2021-12-07 03:34:51,316:INFO:Sampling sampler parameter string OrderedDict([('n_neighbors', 3), ('proportion', 0.1), ('random_state', None)])
# 2021-12-07 03:34:51,316:INFO:{'n_neighbors': 7, 'proportion': 1.0, 'random_state': None}
# 2021-12-07 03:34:51,318:INFO:Sampling sampler parameter string OrderedDict([('n_neighbors', 7), ('proportion', 1.0), ('random_state', None)])
# 2021-12-07 03:34:51,318:INFO:{'n_neighbors': 3, 'proportion': 1.5, 'random_state': None}
# 2021-12-07 03:34:51,318:INFO:Sampling sampler parameter string OrderedDict([('n_neighbors', 3), ('proportion', 1.5), ('random_state', None)])
# 2021-12-07 03:34:51,319:INFO:{'n_neighbors': 3, 'proportion': 0.75, 'random_state': None}
# 2021-12-07 03:34:51,319:INFO:Sampling sampler parameter string OrderedDict([('n_neighbors', 3), ('proportion', 0.75), ('random_state', None)])
# 2021-12-07 03:34:51,319:INFO:{'n_neighbors': 7, 'proportion': 2.0, 'random_state': None}
# 2021-12-07 03:34:51,320:INFO:Sampling sampler parameter string OrderedDict([('n_neighbors', 7), ('proportion', 2.0), ('random_state', None)])
# 2021-12-07 03:34:51,320:INFO:{'n_neighbors': 3, 'proportion': 0.5, 'random_state': None}
# 2021-12-07 03:34:51,321:INFO:Sampling sampler parameter string OrderedDict([('n_neighbors', 3), ('proportion', 0.5), ('random_state', None)])
# 2021-12-07 03:34:51,321:INFO:{'n_neighbors': 5, 'proportion': 1.5, 'random_state': None}
# 2021-12-07 03:34:51,321:INFO:Sampling sampler parameter string OrderedDict([('n_neighbors', 5), ('proportion', 1.5), ('random_state', None)])
# 2021-12-07 03:34:51,322:INFO:{'n_neighbors': 7, 'proportion': 0.75, 'random_state': None}
# 2021-12-07 03:34:51,322:INFO:Sampling sampler parameter string OrderedDict([('n_neighbors', 7), ('proportion', 0.75), ('random_state', None)])
# 2021-12-07 03:34:51,323:INFO:{'n_neighbors': 5, 'proportion': 2.0, 'random_state': None}
# 2021-12-07 03:34:51,323:INFO:Sampling sampler parameter string OrderedDict([('n_neighbors', 5), ('proportion', 2.0), ('random_state', None)])
# 2021-12-07 03:34:51,323:INFO:{'n_neighbors': 3, 'proportion': 2.0, 'random_state': None}
# 2021-12-07 03:34:51,324:INFO:Sampling sampler parameter string OrderedDict([('n_neighbors', 3), ('proportion', 2.0), ('random_state', None)])
# 2021-12-07 03:34:51,326:INFO:{'n_neighbors': 5, 'proportion': 0.75, 'random_state': None}
# 2021-12-07 03:34:51,326:INFO:Sampling sampler parameter string OrderedDict([('n_neighbors', 5), ('proportion', 0.75), ('random_state', None)])
# 2021-12-07 03:34:51,326:INFO:{'n_neighbors': 3, 'proportion': 1.0, 'random_state': None}
# 2021-12-07 03:34:51,327:INFO:Sampling sampler parameter string OrderedDict([('n_neighbors', 3), ('proportion', 1.0), ('random_state', None)])
# 2021-12-07 03:34:51,327:INFO:{'n_neighbors': 7, 'proportion': 0.1, 'random_state': None}
# 2021-12-07 03:34:51,327:INFO:Sampling sampler parameter string OrderedDict([('n_neighbors', 7), ('proportion', 0.1), ('random_state', None)])
# 2021-12-07 03:34:51,328:INFO:{'n_neighbors': 7, 'proportion': 0.25, 'random_state': None}
# 2021-12-07 03:34:51,328:INFO:Sampling sampler parameter string OrderedDict([('n_neighbors', 7), ('proportion', 0.25), ('random_state', None)])
# 2021-12-07 03:34:51,328:INFO:{'n_neighbors': 5, 'proportion': 0.1, 'random_state': None}
# 2021-12-07 03:34:51,329:INFO:Sampling sampler parameter string OrderedDict([('n_neighbors', 5), ('proportion', 0.1), ('random_state', None)])
# 2021-12-07 03:34:51,329:INFO:{'n_neighbors': 3, 'proportion': 0.25, 'random_state': None}
# 2021-12-07 03:34:51,329:INFO:Sampling sampler parameter string OrderedDict([('n_neighbors', 3), ('proportion', 0.25), ('random_state', None)])
# 2021-12-07 03:34:51,330:INFO:{'n_neighbors': 5, 'proportion': 0.25, 'random_state': None}
# 2021-12-07 03:34:51,330:INFO:Sampling sampler parameter string OrderedDict([('n_neighbors', 5), ('proportion', 0.25), ('random_state', None)])
# 2021-12-07 03:34:51,330:INFO:{'n_neighbors': 7, 'proportion': 1.5, 'random_state': None}
# 2021-12-07 03:34:51,331:INFO:Sampling sampler parameter string OrderedDict([('n_neighbors', 7), ('proportion', 1.5), ('random_state', None)])
# 2021-12-07 03:34:51,331:INFO:[{'k_neighbors': 3, 'n_neighbors': 3, 'proportion': 0.1}, {'k_neighbors': 3, 'n_neighbors': 3, 'proportion': 0.25}, {'k_neighbors': 3, 'n_neighbors': 3, 'proportion': 0.5}, {'k_neighbors': 3, 'n_neighbors': 3, 'proportion': 0.75}, {'k_neighbors': 3, 'n_neighbors': 3, 'proportion': 1.0}, {'k_neighbors': 3, 'n_neighbors': 3, 'proportion': 1.5}, {'k_neighbors': 3, 'n_neighbors': 3, 'proportion': 2.0}, {'k_neighbors': 3, 'n_neighbors': 5, 'proportion': 0.1}, {'k_neighbors': 3, 'n_neighbors': 5, 'proportion': 0.25}, {'k_neighbors': 3, 'n_neighbors': 5, 'proportion': 0.5}, {'k_neighbors': 3, 'n_neighbors': 5, 'proportion': 0.75}, {'k_neighbors': 3, 'n_neighbors': 5, 'proportion': 1.0}, {'k_neighbors': 3, 'n_neighbors': 5, 'proportion': 1.5}, {'k_neighbors': 3, 'n_neighbors': 5, 'proportion': 2.0}, {'k_neighbors': 3, 'n_neighbors': 7, 'proportion': 0.1}, {'k_neighbors': 3, 'n_neighbors': 7, 'proportion': 0.25}, {'k_neighbors': 3, 'n_neighbors': 7, 'proportion': 0.5}, {'k_neighbors': 3, 'n_neighbors': 7, 'proportion': 0.75}, {'k_neighbors': 3, 'n_neighbors': 7, 'proportion': 1.0}, {'k_neighbors': 3, 'n_neighbors': 7, 'proportion': 1.5}, {'k_neighbors': 3, 'n_neighbors': 7, 'proportion': 2.0}, {'k_neighbors': 5, 'n_neighbors': 3, 'proportion': 0.1}, {'k_neighbors': 5, 'n_neighbors': 3, 'proportion': 0.25}, {'k_neighbors': 5, 'n_neighbors': 3, 'proportion': 0.5}, {'k_neighbors': 5, 'n_neighbors': 3, 'proportion': 0.75}, {'k_neighbors': 5, 'n_neighbors': 3, 'proportion': 1.0}, {'k_neighbors': 5, 'n_neighbors': 3, 'proportion': 1.5}, {'k_neighbors': 5, 'n_neighbors': 3, 'proportion': 2.0}, {'k_neighbors': 5, 'n_neighbors': 5, 'proportion': 0.1}, {'k_neighbors': 5, 'n_neighbors': 5, 'proportion': 0.25}, {'k_neighbors': 5, 'n_neighbors': 5, 'proportion': 0.5}, {'k_neighbors': 5, 'n_neighbors': 5, 'proportion': 0.75}, {'k_neighbors': 5, 'n_neighbors': 5, 'proportion': 1.0}, {'k_neighbors': 5, 'n_neighbors': 5, 'proportion': 1.5}, {'k_neighbors': 5, 'n_neighbors': 5, 'proportion': 2.0}, {'k_neighbors': 5, 'n_neighbors': 7, 'proportion': 0.1}, {'k_neighbors': 5, 'n_neighbors': 7, 'proportion': 0.25}, {'k_neighbors': 5, 'n_neighbors': 7, 'proportion': 0.5}, {'k_neighbors': 5, 'n_neighbors': 7, 'proportion': 0.75}, {'k_neighbors': 5, 'n_neighbors': 7, 'proportion': 1.0}, {'k_neighbors': 5, 'n_neighbors': 7, 'proportion': 1.5}, {'k_neighbors': 5, 'n_neighbors': 7, 'proportion': 2.0}, {'k_neighbors': 7, 'n_neighbors': 3, 'proportion': 0.1}, {'k_neighbors': 7, 'n_neighbors': 3, 'proportion': 0.25}, {'k_neighbors': 7, 'n_neighbors': 3, 'proportion': 0.5}, {'k_neighbors': 7, 'n_neighbors': 3, 'proportion': 0.75}, {'k_neighbors': 7, 'n_neighbors': 3, 'proportion': 1.0}, {'k_neighbors': 7, 'n_neighbors': 3, 'proportion': 1.5}, {'k_neighbors': 7, 'n_neighbors': 3, 'proportion': 2.0}, {'k_neighbors': 7, 'n_neighbors': 5, 'proportion': 0.1}, {'k_neighbors': 7, 'n_neighbors': 5, 'proportion': 0.25}, {'k_neighbors': 7, 'n_neighbors': 5, 'proportion': 0.5}, {'k_neighbors': 7, 'n_neighbors': 5, 'proportion': 0.75}, {'k_neighbors': 7, 'n_neighbors': 5, 'proportion': 1.0}, {'k_neighbors': 7, 'n_neighbors': 5, 'proportion': 1.5}, {'k_neighbors': 7, 'n_neighbors': 5, 'proportion': 2.0}, {'k_neighbors': 7, 'n_neighbors': 7, 'proportion': 0.1}, {'k_neighbors': 7, 'n_neighbors': 7, 'proportion': 0.25}, {'k_neighbors': 7, 'n_neighbors': 7, 'proportion': 0.5}, {'k_neighbors': 7, 'n_neighbors': 7, 'proportion': 0.75}, {'k_neighbors': 7, 'n_neighbors': 7, 'proportion': 1.0}, {'k_neighbors': 7, 'n_neighbors': 7, 'proportion': 1.5}, {'k_neighbors': 7, 'n_neighbors': 7, 'proportion': 2.0}]
# 2021-12-07 03:34:51,332:INFO:random_indices: [33 37 21  6 23 38  8  0 35  5 11 40 53 47 45 39 41 10 24  3  7  9 49 32
#  12]
# 2021-12-07 03:34:51,332:INFO:[{'k_neighbors': 5, 'n_neighbors': 5, 'proportion': 1.5}, {'k_neighbors': 5, 'n_neighbors': 7, 'proportion': 0.5}, {'k_neighbors': 5, 'n_neighbors': 3, 'proportion': 0.1}, {'k_neighbors': 3, 'n_neighbors': 3, 'proportion': 2.0}, {'k_neighbors': 5, 'n_neighbors': 3, 'proportion': 0.5}, {'k_neighbors': 5, 'n_neighbors': 7, 'proportion': 0.75}, {'k_neighbors': 3, 'n_neighbors': 5, 'proportion': 0.25}, {'k_neighbors': 3, 'n_neighbors': 3, 'proportion': 0.1}, {'k_neighbors': 5, 'n_neighbors': 7, 'proportion': 0.1}, {'k_neighbors': 3, 'n_neighbors': 3, 'proportion': 1.5}, {'k_neighbors': 3, 'n_neighbors': 5, 'proportion': 1.0}, {'k_neighbors': 5, 'n_neighbors': 7, 'proportion': 1.5}, {'k_neighbors': 7, 'n_neighbors': 5, 'proportion': 1.0}, {'k_neighbors': 7, 'n_neighbors': 3, 'proportion': 1.5}, {'k_neighbors': 7, 'n_neighbors': 3, 'proportion': 0.75}, {'k_neighbors': 5, 'n_neighbors': 7, 'proportion': 1.0}, {'k_neighbors': 5, 'n_neighbors': 7, 'proportion': 2.0}, {'k_neighbors': 3, 'n_neighbors': 5, 'proportion': 0.75}, {'k_neighbors': 5, 'n_neighbors': 3, 'proportion': 0.75}, {'k_neighbors': 3, 'n_neighbors': 3, 'proportion': 0.75}, {'k_neighbors': 3, 'n_neighbors': 5, 'proportion': 0.1}, {'k_neighbors': 3, 'n_neighbors': 5, 'proportion': 0.5}, {'k_neighbors': 7, 'n_neighbors': 5, 'proportion': 0.1}, {'k_neighbors': 5, 'n_neighbors': 5, 'proportion': 1.0}, {'k_neighbors': 3, 'n_neighbors': 5, 'proportion': 1.5}]
# 2021-12-07 03:34:51,332:INFO:{'k_neighbors': 5, 'n_neighbors': 5, 'proportion': 1.5, 'random_state': None}
# 2021-12-07 03:34:51,333:INFO:Sampling sampler parameter string OrderedDict([('k_neighbors', 5), ('n_neighbors', 5), ('proportion', 1.5), ('random_state', None)])
# 2021-12-07 03:34:51,333:INFO:{'k_neighbors': 5, 'n_neighbors': 7, 'proportion': 0.5, 'random_state': None}
# 2021-12-07 03:34:51,333:INFO:Sampling sampler parameter string OrderedDict([('k_neighbors', 5), ('n_neighbors', 7), ('proportion', 0.5), ('random_state', None)])
# 2021-12-07 03:34:51,334:INFO:{'k_neighbors': 5, 'n_neighbors': 3, 'proportion': 0.1, 'random_state': None}
# 2021-12-07 03:34:51,334:INFO:Sampling sampler parameter string OrderedDict([('k_neighbors', 5), ('n_neighbors', 3), ('proportion', 0.1), ('random_state', None)])
# 2021-12-07 03:34:51,334:INFO:{'k_neighbors': 3, 'n_neighbors': 3, 'proportion': 2.0, 'random_state': None}
# 2021-12-07 03:34:51,335:INFO:Sampling sampler parameter string OrderedDict([('k_neighbors', 3), ('n_neighbors', 3), ('proportion', 2.0), ('random_state', None)])
# 2021-12-07 03:34:51,335:INFO:{'k_neighbors': 5, 'n_neighbors': 3, 'proportion': 0.5, 'random_state': None}
# 2021-12-07 03:34:51,335:INFO:Sampling sampler parameter string OrderedDict([('k_neighbors', 5), ('n_neighbors', 3), ('proportion', 0.5), ('random_state', None)])
# 2021-12-07 03:34:51,335:INFO:{'k_neighbors': 5, 'n_neighbors': 7, 'proportion': 0.75, 'random_state': None}
# 2021-12-07 03:34:51,336:INFO:Sampling sampler parameter string OrderedDict([('k_neighbors', 5), ('n_neighbors', 7), ('proportion', 0.75), ('random_state', None)])
# 2021-12-07 03:34:51,336:INFO:{'k_neighbors': 3, 'n_neighbors': 5, 'proportion': 0.25, 'random_state': None}
# 2021-12-07 03:34:51,336:INFO:Sampling sampler parameter string OrderedDict([('k_neighbors', 3), ('n_neighbors', 5), ('proportion', 0.25), ('random_state', None)])
# 2021-12-07 03:34:51,337:INFO:{'k_neighbors': 3, 'n_neighbors': 3, 'proportion': 0.1, 'random_state': None}
# 2021-12-07 03:34:51,337:INFO:Sampling sampler parameter string OrderedDict([('k_neighbors', 3), ('n_neighbors', 3), ('proportion', 0.1), ('random_state', None)])
# 2021-12-07 03:34:51,337:INFO:{'k_neighbors': 5, 'n_neighbors': 7, 'proportion': 0.1, 'random_state': None}
# 2021-12-07 03:34:51,338:INFO:Sampling sampler parameter string OrderedDict([('k_neighbors', 5), ('n_neighbors', 7), ('proportion', 0.1), ('random_state', None)])
# 2021-12-07 03:34:51,338:INFO:{'k_neighbors': 3, 'n_neighbors': 3, 'proportion': 1.5, 'random_state': None}
# 2021-12-07 03:34:51,338:INFO:Sampling sampler parameter string OrderedDict([('k_neighbors', 3), ('n_neighbors', 3), ('proportion', 1.5), ('random_state', None)])
# 2021-12-07 03:34:51,339:INFO:{'k_neighbors': 3, 'n_neighbors': 5, 'proportion': 1.0, 'random_state': None}
# 2021-12-07 03:34:51,339:INFO:Sampling sampler parameter string OrderedDict([('k_neighbors', 3), ('n_neighbors', 5), ('proportion', 1.0), ('random_state', None)])
# 2021-12-07 03:34:51,339:INFO:{'k_neighbors': 5, 'n_neighbors': 7, 'proportion': 1.5, 'random_state': None}
# 2021-12-07 03:34:51,340:INFO:Sampling sampler parameter string OrderedDict([('k_neighbors', 5), ('n_neighbors', 7), ('proportion', 1.5), ('random_state', None)])
# 2021-12-07 03:34:51,340:INFO:{'k_neighbors': 7, 'n_neighbors': 5, 'proportion': 1.0, 'random_state': None}
# 2021-12-07 03:34:51,340:INFO:Sampling sampler parameter string OrderedDict([('k_neighbors', 7), ('n_neighbors', 5), ('proportion', 1.0), ('random_state', None)])
# 2021-12-07 03:34:51,341:INFO:{'k_neighbors': 7, 'n_neighbors': 3, 'proportion': 1.5, 'random_state': None}
# 2021-12-07 03:34:51,341:INFO:Sampling sampler parameter string OrderedDict([('k_neighbors', 7), ('n_neighbors', 3), ('proportion', 1.5), ('random_state', None)])
# 2021-12-07 03:34:51,341:INFO:{'k_neighbors': 7, 'n_neighbors': 3, 'proportion': 0.75, 'random_state': None}
# 2021-12-07 03:34:51,342:INFO:Sampling sampler parameter string OrderedDict([('k_neighbors', 7), ('n_neighbors', 3), ('proportion', 0.75), ('random_state', None)])
# 2021-12-07 03:34:51,342:INFO:{'k_neighbors': 5, 'n_neighbors': 7, 'proportion': 1.0, 'random_state': None}
# 2021-12-07 03:34:51,342:INFO:Sampling sampler parameter string OrderedDict([('k_neighbors', 5), ('n_neighbors', 7), ('proportion', 1.0), ('random_state', None)])
# 2021-12-07 03:34:51,343:INFO:{'k_neighbors': 5, 'n_neighbors': 7, 'proportion': 2.0, 'random_state': None}
# 2021-12-07 03:34:51,343:INFO:Sampling sampler parameter string OrderedDict([('k_neighbors', 5), ('n_neighbors', 7), ('proportion', 2.0), ('random_state', None)])
# 2021-12-07 03:34:51,343:INFO:{'k_neighbors': 3, 'n_neighbors': 5, 'proportion': 0.75, 'random_state': None}
# 2021-12-07 03:34:51,343:INFO:Sampling sampler parameter string OrderedDict([('k_neighbors', 3), ('n_neighbors', 5), ('proportion', 0.75), ('random_state', None)])
# 2021-12-07 03:34:51,344:INFO:{'k_neighbors': 5, 'n_neighbors': 3, 'proportion': 0.75, 'random_state': None}
# 2021-12-07 03:34:51,344:INFO:Sampling sampler parameter string OrderedDict([('k_neighbors', 5), ('n_neighbors', 3), ('proportion', 0.75), ('random_state', None)])
# 2021-12-07 03:34:51,344:INFO:{'k_neighbors': 3, 'n_neighbors': 3, 'proportion': 0.75, 'random_state': None}
# 2021-12-07 03:34:51,345:INFO:Sampling sampler parameter string OrderedDict([('k_neighbors', 3), ('n_neighbors', 3), ('proportion', 0.75), ('random_state', None)])
# 2021-12-07 03:34:51,345:INFO:{'k_neighbors': 3, 'n_neighbors': 5, 'proportion': 0.1, 'random_state': None}
# 2021-12-07 03:34:51,345:INFO:Sampling sampler parameter string OrderedDict([('k_neighbors', 3), ('n_neighbors', 5), ('proportion', 0.1), ('random_state', None)])
# 2021-12-07 03:34:51,346:INFO:{'k_neighbors': 3, 'n_neighbors': 5, 'proportion': 0.5, 'random_state': None}
# 2021-12-07 03:34:51,346:INFO:Sampling sampler parameter string OrderedDict([('k_neighbors', 3), ('n_neighbors', 5), ('proportion', 0.5), ('random_state', None)])
# 2021-12-07 03:34:51,346:INFO:{'k_neighbors': 7, 'n_neighbors': 5, 'proportion': 0.1, 'random_state': None}
# 2021-12-07 03:34:51,347:INFO:Sampling sampler parameter string OrderedDict([('k_neighbors', 7), ('n_neighbors', 5), ('proportion', 0.1), ('random_state', None)])
# 2021-12-07 03:34:51,347:INFO:{'k_neighbors': 5, 'n_neighbors': 5, 'proportion': 1.0, 'random_state': None}
# 2021-12-07 03:34:51,347:INFO:Sampling sampler parameter string OrderedDict([('k_neighbors', 5), ('n_neighbors', 5), ('proportion', 1.0), ('random_state', None)])
# 2021-12-07 03:34:51,348:INFO:{'k_neighbors': 3, 'n_neighbors': 5, 'proportion': 1.5, 'random_state': None}
# 2021-12-07 03:34:51,348:INFO:Sampling sampler parameter string OrderedDict([('k_neighbors', 3), ('n_neighbors', 5), ('proportion', 1.5), ('random_state', None)])
# 2021-12-07 03:34:51,348:INFO:[{'k_neighbors': 3, 'n_neighbors': 3, 'proportion': 0.1}, {'k_neighbors': 3, 'n_neighbors': 3, 'proportion': 0.25}, {'k_neighbors': 3, 'n_neighbors': 3, 'proportion': 0.5}, {'k_neighbors': 3, 'n_neighbors': 3, 'proportion': 0.75}, {'k_neighbors': 3, 'n_neighbors': 3, 'proportion': 1.0}, {'k_neighbors': 3, 'n_neighbors': 3, 'proportion': 1.5}, {'k_neighbors': 3, 'n_neighbors': 3, 'proportion': 2.0}, {'k_neighbors': 3, 'n_neighbors': 5, 'proportion': 0.1}, {'k_neighbors': 3, 'n_neighbors': 5, 'proportion': 0.25}, {'k_neighbors': 3, 'n_neighbors': 5, 'proportion': 0.5}, {'k_neighbors': 3, 'n_neighbors': 5, 'proportion': 0.75}, {'k_neighbors': 3, 'n_neighbors': 5, 'proportion': 1.0}, {'k_neighbors': 3, 'n_neighbors': 5, 'proportion': 1.5}, {'k_neighbors': 3, 'n_neighbors': 5, 'proportion': 2.0}, {'k_neighbors': 3, 'n_neighbors': 7, 'proportion': 0.1}, {'k_neighbors': 3, 'n_neighbors': 7, 'proportion': 0.25}, {'k_neighbors': 3, 'n_neighbors': 7, 'proportion': 0.5}, {'k_neighbors': 3, 'n_neighbors': 7, 'proportion': 0.75}, {'k_neighbors': 3, 'n_neighbors': 7, 'proportion': 1.0}, {'k_neighbors': 3, 'n_neighbors': 7, 'proportion': 1.5}, {'k_neighbors': 3, 'n_neighbors': 7, 'proportion': 2.0}, {'k_neighbors': 5, 'n_neighbors': 3, 'proportion': 0.1}, {'k_neighbors': 5, 'n_neighbors': 3, 'proportion': 0.25}, {'k_neighbors': 5, 'n_neighbors': 3, 'proportion': 0.5}, {'k_neighbors': 5, 'n_neighbors': 3, 'proportion': 0.75}, {'k_neighbors': 5, 'n_neighbors': 3, 'proportion': 1.0}, {'k_neighbors': 5, 'n_neighbors': 3, 'proportion': 1.5}, {'k_neighbors': 5, 'n_neighbors': 3, 'proportion': 2.0}, {'k_neighbors': 5, 'n_neighbors': 5, 'proportion': 0.1}, {'k_neighbors': 5, 'n_neighbors': 5, 'proportion': 0.25}, {'k_neighbors': 5, 'n_neighbors': 5, 'proportion': 0.5}, {'k_neighbors': 5, 'n_neighbors': 5, 'proportion': 0.75}, {'k_neighbors': 5, 'n_neighbors': 5, 'proportion': 1.0}, {'k_neighbors': 5, 'n_neighbors': 5, 'proportion': 1.5}, {'k_neighbors': 5, 'n_neighbors': 5, 'proportion': 2.0}, {'k_neighbors': 5, 'n_neighbors': 7, 'proportion': 0.1}, {'k_neighbors': 5, 'n_neighbors': 7, 'proportion': 0.25}, {'k_neighbors': 5, 'n_neighbors': 7, 'proportion': 0.5}, {'k_neighbors': 5, 'n_neighbors': 7, 'proportion': 0.75}, {'k_neighbors': 5, 'n_neighbors': 7, 'proportion': 1.0}, {'k_neighbors': 5, 'n_neighbors': 7, 'proportion': 1.5}, {'k_neighbors': 5, 'n_neighbors': 7, 'proportion': 2.0}, {'k_neighbors': 7, 'n_neighbors': 3, 'proportion': 0.1}, {'k_neighbors': 7, 'n_neighbors': 3, 'proportion': 0.25}, {'k_neighbors': 7, 'n_neighbors': 3, 'proportion': 0.5}, {'k_neighbors': 7, 'n_neighbors': 3, 'proportion': 0.75}, {'k_neighbors': 7, 'n_neighbors': 3, 'proportion': 1.0}, {'k_neighbors': 7, 'n_neighbors': 3, 'proportion': 1.5}, {'k_neighbors': 7, 'n_neighbors': 3, 'proportion': 2.0}, {'k_neighbors': 7, 'n_neighbors': 5, 'proportion': 0.1}, {'k_neighbors': 7, 'n_neighbors': 5, 'proportion': 0.25}, {'k_neighbors': 7, 'n_neighbors': 5, 'proportion': 0.5}, {'k_neighbors': 7, 'n_neighbors': 5, 'proportion': 0.75}, {'k_neighbors': 7, 'n_neighbors': 5, 'proportion': 1.0}, {'k_neighbors': 7, 'n_neighbors': 5, 'proportion': 1.5}, {'k_neighbors': 7, 'n_neighbors': 5, 'proportion': 2.0}, {'k_neighbors': 7, 'n_neighbors': 7, 'proportion': 0.1}, {'k_neighbors': 7, 'n_neighbors': 7, 'proportion': 0.25}, {'k_neighbors': 7, 'n_neighbors': 7, 'proportion': 0.5}, {'k_neighbors': 7, 'n_neighbors': 7, 'proportion': 0.75}, {'k_neighbors': 7, 'n_neighbors': 7, 'proportion': 1.0}, {'k_neighbors': 7, 'n_neighbors': 7, 'proportion': 1.5}, {'k_neighbors': 7, 'n_neighbors': 7, 'proportion': 2.0}]
# 2021-12-07 03:34:51,349:INFO:random_indices: [44 42  7 50 40 20 13 34 60 56 52 37 58  5 12 16 46  0 25 32  2  4 11 19
#   6]
# 2021-12-07 03:34:51,350:INFO:[{'k_neighbors': 7, 'n_neighbors': 3, 'proportion': 0.5}, {'k_neighbors': 7, 'n_neighbors': 3, 'proportion': 0.1}, {'k_neighbors': 3, 'n_neighbors': 5, 'proportion': 0.1}, {'k_neighbors': 7, 'n_neighbors': 5, 'proportion': 0.25}, {'k_neighbors': 5, 'n_neighbors': 7, 'proportion': 1.5}, {'k_neighbors': 3, 'n_neighbors': 7, 'proportion': 2.0}, {'k_neighbors': 3, 'n_neighbors': 5, 'proportion': 2.0}, {'k_neighbors': 5, 'n_neighbors': 5, 'proportion': 2.0}, {'k_neighbors': 7, 'n_neighbors': 7, 'proportion': 1.0}, {'k_neighbors': 7, 'n_neighbors': 7, 'proportion': 0.1}, {'k_neighbors': 7, 'n_neighbors': 5, 'proportion': 0.75}, {'k_neighbors': 5, 'n_neighbors': 7, 'proportion': 0.5}, {'k_neighbors': 7, 'n_neighbors': 7, 'proportion': 0.5}, {'k_neighbors': 3, 'n_neighbors': 3, 'proportion': 1.5}, {'k_neighbors': 3, 'n_neighbors': 5, 'proportion': 1.5}, {'k_neighbors': 3, 'n_neighbors': 7, 'proportion': 0.5}, {'k_neighbors': 7, 'n_neighbors': 3, 'proportion': 1.0}, {'k_neighbors': 3, 'n_neighbors': 3, 'proportion': 0.1}, {'k_neighbors': 5, 'n_neighbors': 3, 'proportion': 1.0}, {'k_neighbors': 5, 'n_neighbors': 5, 'proportion': 1.0}, {'k_neighbors': 3, 'n_neighbors': 3, 'proportion': 0.5}, {'k_neighbors': 3, 'n_neighbors': 3, 'proportion': 1.0}, {'k_neighbors': 3, 'n_neighbors': 5, 'proportion': 1.0}, {'k_neighbors': 3, 'n_neighbors': 7, 'proportion': 1.5}, {'k_neighbors': 3, 'n_neighbors': 3, 'proportion': 2.0}]
# 2021-12-07 03:34:51,350:INFO:{'k_neighbors': 7, 'n_neighbors': 3, 'proportion': 0.5, 'random_state': None}
# 2021-12-07 03:34:51,356:INFO:Sampling sampler parameter string OrderedDict([('k_neighbors', 7), ('n_neighbors', 3), ('proportion', 0.5), ('random_state', None)])
# 2021-12-07 03:34:51,357:INFO:{'k_neighbors': 7, 'n_neighbors': 3, 'proportion': 0.1, 'random_state': None}
# 2021-12-07 03:34:51,357:INFO:Sampling sampler parameter string OrderedDict([('k_neighbors', 7), ('n_neighbors', 3), ('proportion', 0.1), ('random_state', None)])
# 2021-12-07 03:34:51,357:INFO:{'k_neighbors': 3, 'n_neighbors': 5, 'proportion': 0.1, 'random_state': None}
# 2021-12-07 03:34:51,358:INFO:Sampling sampler parameter string OrderedDict([('k_neighbors', 3), ('n_neighbors', 5), ('proportion', 0.1), ('random_state', None)])
# 2021-12-07 03:34:51,358:INFO:{'k_neighbors': 7, 'n_neighbors': 5, 'proportion': 0.25, 'random_state': None}
# 2021-12-07 03:34:51,358:INFO:Sampling sampler parameter string OrderedDict([('k_neighbors', 7), ('n_neighbors', 5), ('proportion', 0.25), ('random_state', None)])
# 2021-12-07 03:34:51,359:INFO:{'k_neighbors': 5, 'n_neighbors': 7, 'proportion': 1.5, 'random_state': None}
# 2021-12-07 03:34:51,359:INFO:Sampling sampler parameter string OrderedDict([('k_neighbors', 5), ('n_neighbors', 7), ('proportion', 1.5), ('random_state', None)])
# 2021-12-07 03:34:51,359:INFO:{'k_neighbors': 3, 'n_neighbors': 7, 'proportion': 2.0, 'random_state': None}
# 2021-12-07 03:34:51,360:INFO:Sampling sampler parameter string OrderedDict([('k_neighbors', 3), ('n_neighbors', 7), ('proportion', 2.0), ('random_state', None)])
# 2021-12-07 03:34:51,360:INFO:{'k_neighbors': 3, 'n_neighbors': 5, 'proportion': 2.0, 'random_state': None}
# 2021-12-07 03:34:51,360:INFO:Sampling sampler parameter string OrderedDict([('k_neighbors', 3), ('n_neighbors', 5), ('proportion', 2.0), ('random_state', None)])
# 2021-12-07 03:34:51,361:INFO:{'k_neighbors': 5, 'n_neighbors': 5, 'proportion': 2.0, 'random_state': None}
# 2021-12-07 03:34:51,361:INFO:Sampling sampler parameter string OrderedDict([('k_neighbors', 5), ('n_neighbors', 5), ('proportion', 2.0), ('random_state', None)])
# 2021-12-07 03:34:51,361:INFO:{'k_neighbors': 7, 'n_neighbors': 7, 'proportion': 1.0, 'random_state': None}
# 2021-12-07 03:34:51,362:INFO:Sampling sampler parameter string OrderedDict([('k_neighbors', 7), ('n_neighbors', 7), ('proportion', 1.0), ('random_state', None)])
# 2021-12-07 03:34:51,362:INFO:{'k_neighbors': 7, 'n_neighbors': 7, 'proportion': 0.1, 'random_state': None}
# 2021-12-07 03:34:51,362:INFO:Sampling sampler parameter string OrderedDict([('k_neighbors', 7), ('n_neighbors', 7), ('proportion', 0.1), ('random_state', None)])
# 2021-12-07 03:34:51,363:INFO:{'k_neighbors': 7, 'n_neighbors': 5, 'proportion': 0.75, 'random_state': None}
# 2021-12-07 03:34:51,363:INFO:Sampling sampler parameter string OrderedDict([('k_neighbors', 7), ('n_neighbors', 5), ('proportion', 0.75), ('random_state', None)])
# 2021-12-07 03:34:51,363:INFO:{'k_neighbors': 5, 'n_neighbors': 7, 'proportion': 0.5, 'random_state': None}
# 2021-12-07 03:34:51,364:INFO:Sampling sampler parameter string OrderedDict([('k_neighbors', 5), ('n_neighbors', 7), ('proportion', 0.5), ('random_state', None)])
# 2021-12-07 03:34:51,364:INFO:{'k_neighbors': 7, 'n_neighbors': 7, 'proportion': 0.5, 'random_state': None}
# 2021-12-07 03:34:51,364:INFO:Sampling sampler parameter string OrderedDict([('k_neighbors', 7), ('n_neighbors', 7), ('proportion', 0.5), ('random_state', None)])
# 2021-12-07 03:34:51,365:INFO:{'k_neighbors': 3, 'n_neighbors': 3, 'proportion': 1.5, 'random_state': None}
# 2021-12-07 03:34:51,365:INFO:Sampling sampler parameter string OrderedDict([('k_neighbors', 3), ('n_neighbors', 3), ('proportion', 1.5), ('random_state', None)])
# 2021-12-07 03:34:51,365:INFO:{'k_neighbors': 3, 'n_neighbors': 5, 'proportion': 1.5, 'random_state': None}
# 2021-12-07 03:34:51,365:INFO:Sampling sampler parameter string OrderedDict([('k_neighbors', 3), ('n_neighbors', 5), ('proportion', 1.5), ('random_state', None)])
# 2021-12-07 03:34:51,366:INFO:{'k_neighbors': 3, 'n_neighbors': 7, 'proportion': 0.5, 'random_state': None}
# 2021-12-07 03:34:51,366:INFO:Sampling sampler parameter string OrderedDict([('k_neighbors', 3), ('n_neighbors', 7), ('proportion', 0.5), ('random_state', None)])
# 2021-12-07 03:34:51,367:INFO:{'k_neighbors': 7, 'n_neighbors': 3, 'proportion': 1.0, 'random_state': None}
# 2021-12-07 03:34:51,367:INFO:Sampling sampler parameter string OrderedDict([('k_neighbors', 7), ('n_neighbors', 3), ('proportion', 1.0), ('random_state', None)])
# 2021-12-07 03:34:51,367:INFO:{'k_neighbors': 3, 'n_neighbors': 3, 'proportion': 0.1, 'random_state': None}
# 2021-12-07 03:34:51,368:INFO:Sampling sampler parameter string OrderedDict([('k_neighbors', 3), ('n_neighbors', 3), ('proportion', 0.1), ('random_state', None)])
# 2021-12-07 03:34:51,368:INFO:{'k_neighbors': 5, 'n_neighbors': 3, 'proportion': 1.0, 'random_state': None}
# 2021-12-07 03:34:51,371:INFO:Sampling sampler parameter string OrderedDict([('k_neighbors', 5), ('n_neighbors', 3), ('proportion', 1.0), ('random_state', None)])
# 2021-12-07 03:34:51,371:INFO:{'k_neighbors': 5, 'n_neighbors': 5, 'proportion': 1.0, 'random_state': None}
# 2021-12-07 03:34:51,372:INFO:Sampling sampler parameter string OrderedDict([('k_neighbors', 5), ('n_neighbors', 5), ('proportion', 1.0), ('random_state', None)])
# 2021-12-07 03:34:51,372:INFO:{'k_neighbors': 3, 'n_neighbors': 3, 'proportion': 0.5, 'random_state': None}
# 2021-12-07 03:34:51,372:INFO:Sampling sampler parameter string OrderedDict([('k_neighbors', 3), ('n_neighbors', 3), ('proportion', 0.5), ('random_state', None)])
# 2021-12-07 03:34:51,373:INFO:{'k_neighbors': 3, 'n_neighbors': 3, 'proportion': 1.0, 'random_state': None}
# 2021-12-07 03:34:51,373:INFO:Sampling sampler parameter string OrderedDict([('k_neighbors', 3), ('n_neighbors', 3), ('proportion', 1.0), ('random_state', None)])
# 2021-12-07 03:34:51,373:INFO:{'k_neighbors': 3, 'n_neighbors': 5, 'proportion': 1.0, 'random_state': None}
# 2021-12-07 03:34:51,374:INFO:Sampling sampler parameter string OrderedDict([('k_neighbors', 3), ('n_neighbors', 5), ('proportion', 1.0), ('random_state', None)])
# 2021-12-07 03:34:51,374:INFO:{'k_neighbors': 3, 'n_neighbors': 7, 'proportion': 1.5, 'random_state': None}
# 2021-12-07 03:34:51,375:INFO:Sampling sampler parameter string OrderedDict([('k_neighbors', 3), ('n_neighbors', 7), ('proportion', 1.5), ('random_state', None)])
# 2021-12-07 03:34:51,375:INFO:{'k_neighbors': 3, 'n_neighbors': 3, 'proportion': 2.0, 'random_state': None}
# 2021-12-07 03:34:51,376:INFO:Sampling sampler parameter string OrderedDict([('k_neighbors', 3), ('n_neighbors', 3), ('proportion', 2.0), ('random_state', None)])
# 2021-12-07 03:34:51,377:INFO:[{'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 3, 'p': 0.01, 'proportion': 0.1, 'voting': 'majority'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 3, 'p': 0.01, 'proportion': 0.1, 'voting': 'consensus'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 3, 'p': 0.01, 'proportion': 0.25, 'voting': 'majority'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 3, 'p': 0.01, 'proportion': 0.25, 'voting': 'consensus'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 3, 'p': 0.01, 'proportion': 0.5, 'voting': 'majority'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 3, 'p': 0.01, 'proportion': 0.5, 'voting': 'consensus'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 3, 'p': 0.01, 'proportion': 0.75, 'voting': 'majority'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 3, 'p': 0.01, 'proportion': 0.75, 'voting': 'consensus'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 3, 'p': 0.01, 'proportion': 1.0, 'voting': 'majority'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 3, 'p': 0.01, 'proportion': 1.0, 'voting': 'consensus'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 3, 'p': 0.01, 'proportion': 1.5, 'voting': 'majority'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 3, 'p': 0.01, 'proportion': 1.5, 'voting': 'consensus'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 3, 'p': 0.01, 'proportion': 2.0, 'voting': 'majority'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 3, 'p': 0.01, 'proportion': 2.0, 'voting': 'consensus'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 5, 'p': 0.01, 'proportion': 0.1, 'voting': 'majority'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 5, 'p': 0.01, 'proportion': 0.1, 'voting': 'consensus'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 5, 'p': 0.01, 'proportion': 0.25, 'voting': 'majority'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 5, 'p': 0.01, 'proportion': 0.25, 'voting': 'consensus'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 5, 'p': 0.01, 'proportion': 0.5, 'voting': 'majority'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 5, 'p': 0.01, 'proportion': 0.5, 'voting': 'consensus'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 5, 'p': 0.01, 'proportion': 0.75, 'voting': 'majority'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 5, 'p': 0.01, 'proportion': 0.75, 'voting': 'consensus'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 5, 'p': 0.01, 'proportion': 1.0, 'voting': 'majority'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 5, 'p': 0.01, 'proportion': 1.0, 'voting': 'consensus'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 5, 'p': 0.01, 'proportion': 1.5, 'voting': 'majority'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 5, 'p': 0.01, 'proportion': 1.5, 'voting': 'consensus'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 5, 'p': 0 ...
# 2021-12-07 03:34:51,383:INFO:random_indices: [27 19 10 28 11 21 14 32  9 20 36  7  2 40  1  3 23 30 41 24  5 18 37 16
#  39]
# 2021-12-07 03:34:51,383:INFO:[{'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 5, 'p': 0.01, 'proportion': 2.0, 'voting': 'consensus'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 5, 'p': 0.01, 'proportion': 0.5, 'voting': 'consensus'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 3, 'p': 0.01, 'proportion': 1.5, 'voting': 'majority'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 7, 'p': 0.01, 'proportion': 0.1, 'voting': 'majority'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 3, 'p': 0.01, 'proportion': 1.5, 'voting': 'consensus'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 5, 'p': 0.01, 'proportion': 0.75, 'voting': 'consensus'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 5, 'p': 0.01, 'proportion': 0.1, 'voting': 'majority'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 7, 'p': 0.01, 'proportion': 0.5, 'voting': 'majority'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 3, 'p': 0.01, 'proportion': 1.0, 'voting': 'consensus'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 5, 'p': 0.01, 'proportion': 0.75, 'voting': 'majority'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 7, 'p': 0.01, 'proportion': 1.0, 'voting': 'majority'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 3, 'p': 0.01, 'proportion': 0.75, 'voting': 'consensus'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 3, 'p': 0.01, 'proportion': 0.25, 'voting': 'majority'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 7, 'p': 0.01, 'proportion': 2.0, 'voting': 'majority'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 3, 'p': 0.01, 'proportion': 0.1, 'voting': 'consensus'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 3, 'p': 0.01, 'proportion': 0.25, 'voting': 'consensus'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 5, 'p': 0.01, 'proportion': 1.0, 'voting': 'consensus'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 7, 'p': 0.01, 'proportion': 0.25, 'voting': 'majority'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 7, 'p': 0.01, 'proportion': 2.0, 'voting': 'consensus'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 5, 'p': 0.01, 'proportion': 1.5, 'voting': 'majority'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 3, 'p': 0.01, 'proportion': 0.5, 'voting': 'consensus'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 5, 'p': 0.01, 'proportion': 0.5, 'voting': 'majority'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 7, 'p': 0.01, 'proportion': 1.0, 'voting': 'consensus'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 5, 'p': 0.01, 'proportion': 0.25, 'voting': 'majority'}, {'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 7, 'p': 0.01, 'proportion': 1.5, 'voting': 'consensus'}]
# 2021-12-07 03:34:51,387:INFO:{'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 5, 'p': 0.01, 'proportion': 2.0, 'voting': 'consensus', 'random_state': None}
# 2021-12-07 03:34:51,388:INFO:Sampling sampler parameter string OrderedDict([('classifier', DecisionTreeClassifier(random_state=2)), ('k', 3), ('n_folds', 9), ('n_neighbors', 5), ('p', 0.01), ('proportion', 2.0), ('random_state', None), ('voting', 'consensus')])
# 2021-12-07 03:34:51,388:INFO:{'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 5, 'p': 0.01, 'proportion': 0.5, 'voting': 'consensus', 'random_state': None}
# 2021-12-07 03:34:51,389:INFO:Sampling sampler parameter string OrderedDict([('classifier', DecisionTreeClassifier(random_state=2)), ('k', 3), ('n_folds', 9), ('n_neighbors', 5), ('p', 0.01), ('proportion', 0.5), ('random_state', None), ('voting', 'consensus')])
# 2021-12-07 03:34:51,389:INFO:{'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 3, 'p': 0.01, 'proportion': 1.5, 'voting': 'majority', 'random_state': None}
# 2021-12-07 03:34:51,390:INFO:Sampling sampler parameter string OrderedDict([('classifier', DecisionTreeClassifier(random_state=2)), ('k', 3), ('n_folds', 9), ('n_neighbors', 3), ('p', 0.01), ('proportion', 1.5), ('random_state', None), ('voting', 'majority')])
# 2021-12-07 03:34:51,391:INFO:{'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 7, 'p': 0.01, 'proportion': 0.1, 'voting': 'majority', 'random_state': None}
# 2021-12-07 03:34:51,391:INFO:Sampling sampler parameter string OrderedDict([('classifier', DecisionTreeClassifier(random_state=2)), ('k', 3), ('n_folds', 9), ('n_neighbors', 7), ('p', 0.01), ('proportion', 0.1), ('random_state', None), ('voting', 'majority')])
# 2021-12-07 03:34:51,392:INFO:{'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 3, 'p': 0.01, 'proportion': 1.5, 'voting': 'consensus', 'random_state': None}
# 2021-12-07 03:34:51,392:INFO:Sampling sampler parameter string OrderedDict([('classifier', DecisionTreeClassifier(random_state=2)), ('k', 3), ('n_folds', 9), ('n_neighbors', 3), ('p', 0.01), ('proportion', 1.5), ('random_state', None), ('voting', 'consensus')])
# 2021-12-07 03:34:51,393:INFO:{'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 5, 'p': 0.01, 'proportion': 0.75, 'voting': 'consensus', 'random_state': None}
# 2021-12-07 03:34:51,393:INFO:Sampling sampler parameter string OrderedDict([('classifier', DecisionTreeClassifier(random_state=2)), ('k', 3), ('n_folds', 9), ('n_neighbors', 5), ('p', 0.01), ('proportion', 0.75), ('random_state', None), ('voting', 'consensus')])
# 2021-12-07 03:34:51,394:INFO:{'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 5, 'p': 0.01, 'proportion': 0.1, 'voting': 'majority', 'random_state': None}
# 2021-12-07 03:34:51,394:INFO:Sampling sampler parameter string OrderedDict([('classifier', DecisionTreeClassifier(random_state=2)), ('k', 3), ('n_folds', 9), ('n_neighbors', 5), ('p', 0.01), ('proportion', 0.1), ('random_state', None), ('voting', 'majority')])
# 2021-12-07 03:34:51,395:INFO:{'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 7, 'p': 0.01, 'proportion': 0.5, 'voting': 'majority', 'random_state': None}
# 2021-12-07 03:34:51,396:INFO:Sampling sampler parameter string OrderedDict([('classifier', DecisionTreeClassifier(random_state=2)), ('k', 3), ('n_folds', 9), ('n_neighbors', 7), ('p', 0.01), ('proportion', 0.5), ('random_state', None), ('voting', 'majority')])
# 2021-12-07 03:34:51,396:INFO:{'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 3, 'p': 0.01, 'proportion': 1.0, 'voting': 'consensus', 'random_state': None}
# 2021-12-07 03:34:51,397:INFO:Sampling sampler parameter string OrderedDict([('classifier', DecisionTreeClassifier(random_state=2)), ('k', 3), ('n_folds', 9), ('n_neighbors', 3), ('p', 0.01), ('proportion', 1.0), ('random_state', None), ('voting', 'consensus')])
# 2021-12-07 03:34:51,397:INFO:{'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 5, 'p': 0.01, 'proportion': 0.75, 'voting': 'majority', 'random_state': None}
# 2021-12-07 03:34:51,398:INFO:Sampling sampler parameter string OrderedDict([('classifier', DecisionTreeClassifier(random_state=2)), ('k', 3), ('n_folds', 9), ('n_neighbors', 5), ('p', 0.01), ('proportion', 0.75), ('random_state', None), ('voting', 'majority')])
# 2021-12-07 03:34:51,399:INFO:{'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 7, 'p': 0.01, 'proportion': 1.0, 'voting': 'majority', 'random_state': None}
# 2021-12-07 03:34:51,399:INFO:Sampling sampler parameter string OrderedDict([('classifier', DecisionTreeClassifier(random_state=2)), ('k', 3), ('n_folds', 9), ('n_neighbors', 7), ('p', 0.01), ('proportion', 1.0), ('random_state', None), ('voting', 'majority')])
# 2021-12-07 03:34:51,400:INFO:{'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 3, 'p': 0.01, 'proportion': 0.75, 'voting': 'consensus', 'random_state': None}
# 2021-12-07 03:34:51,401:INFO:Sampling sampler parameter string OrderedDict([('classifier', DecisionTreeClassifier(random_state=2)), ('k', 3), ('n_folds', 9), ('n_neighbors', 3), ('p', 0.01), ('proportion', 0.75), ('random_state', None), ('voting', 'consensus')])
# 2021-12-07 03:34:51,401:INFO:{'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 3, 'p': 0.01, 'proportion': 0.25, 'voting': 'majority', 'random_state': None}
# 2021-12-07 03:34:51,402:INFO:Sampling sampler parameter string OrderedDict([('classifier', DecisionTreeClassifier(random_state=2)), ('k', 3), ('n_folds', 9), ('n_neighbors', 3), ('p', 0.01), ('proportion', 0.25), ('random_state', None), ('voting', 'majority')])
# 2021-12-07 03:34:51,402:INFO:{'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 7, 'p': 0.01, 'proportion': 2.0, 'voting': 'majority', 'random_state': None}
# 2021-12-07 03:34:51,403:INFO:Sampling sampler parameter string OrderedDict([('classifier', DecisionTreeClassifier(random_state=2)), ('k', 3), ('n_folds', 9), ('n_neighbors', 7), ('p', 0.01), ('proportion', 2.0), ('random_state', None), ('voting', 'majority')])
# 2021-12-07 03:34:51,404:INFO:{'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 3, 'p': 0.01, 'proportion': 0.1, 'voting': 'consensus', 'random_state': None}
# 2021-12-07 03:34:51,404:INFO:Sampling sampler parameter string OrderedDict([('classifier', DecisionTreeClassifier(random_state=2)), ('k', 3), ('n_folds', 9), ('n_neighbors', 3), ('p', 0.01), ('proportion', 0.1), ('random_state', None), ('voting', 'consensus')])
# 2021-12-07 03:34:51,405:INFO:{'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 3, 'p': 0.01, 'proportion': 0.25, 'voting': 'consensus', 'random_state': None}
# 2021-12-07 03:34:51,405:INFO:Sampling sampler parameter string OrderedDict([('classifier', DecisionTreeClassifier(random_state=2)), ('k', 3), ('n_folds', 9), ('n_neighbors', 3), ('p', 0.01), ('proportion', 0.25), ('random_state', None), ('voting', 'consensus')])
# 2021-12-07 03:34:51,406:INFO:{'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 5, 'p': 0.01, 'proportion': 1.0, 'voting': 'consensus', 'random_state': None}
# 2021-12-07 03:34:51,406:INFO:Sampling sampler parameter string OrderedDict([('classifier', DecisionTreeClassifier(random_state=2)), ('k', 3), ('n_folds', 9), ('n_neighbors', 5), ('p', 0.01), ('proportion', 1.0), ('random_state', None), ('voting', 'consensus')])
# 2021-12-07 03:34:51,410:INFO:{'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 7, 'p': 0.01, 'proportion': 0.25, 'voting': 'majority', 'random_state': None}
# 2021-12-07 03:34:51,410:INFO:Sampling sampler parameter string OrderedDict([('classifier', DecisionTreeClassifier(random_state=2)), ('k', 3), ('n_folds', 9), ('n_neighbors', 7), ('p', 0.01), ('proportion', 0.25), ('random_state', None), ('voting', 'majority')])
# 2021-12-07 03:34:51,411:INFO:{'classifier': DecisionTreeClassifier(random_state=2), 'k': 3, 'n_folds': 9, 'n_neighbors': 7, 'p': 0.01, 'proportion': 2.0, 'voting': 'consensus', 'random_state': None}
# 2021-12-07 03:34:51,411:INFO:Sampling sampler parameter string OrderedDict([('classifier', DecisionTreeClassifier(random_state=2)), ('k', 3), ('n_folds', 9), ('n_neighbors', 7), ('p', 0.01), ('proportion', 2.0), ('random_state', None), ('voting', 'consensus')])
# ...
# /home/nmc/anaconda3/envs/deeplearning/lib/python3.9/site-packages/smote_variants/_smote_variants.py:19753: RuntimeWarning: invalid value encountered in true_divide
#   results['mcc'] = mcc_num/np.sqrt(mcc_denom)
# /home/nmc/anaconda3/envs/deeplearning/lib/python3.9/site-packages/smote_variants/_smote_variants.py:19760: RuntimeWarning: invalid value encountered in long_scalars
#   results['ltp'] = results['tp']*np.log(results['tp']/(tp_fp*tp_fn))
# /home/nmc/anaconda3/envs/deeplearning/lib/python3.9/site-packages/smote_variants/_smote_variants.py:19761: RuntimeWarning: invalid value encountered in long_scalars
#   results['lfp'] = results['fp']*np.log(results['fp']/(tp_fp*tn_fp))
# 2021-12-07 03:36:27,333:INFO:Evaluation do the evaluation 03subcl5-800-7-30-BI-full SMOTE MLPClassifierWrapper
# /home/nmc/anaconda3/envs/deeplearning/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/nmc/anaconda3/envs/deeplearning/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# 2021-12-07 03:36:27,507:INFO:Evaluation do the evaluation 03subcl5-800-7-30-BI-full SMOTE MLPClassifierWrapper
# /home/nmc/anaconda3/envs/deeplearning/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/nmc/anaconda3/envs/deeplearning/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/nmc/anaconda3/envs/deeplearning/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/nmc/anaconda3/envs/deeplearning/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/nmc/anaconda3/envs/deeplearning/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# 2021-12-07 03:36:27,948:INFO:Evaluation do the evaluation 03subcl5-800-7-30-BI-full SMOTE KNeighborsClassifier
# /home/nmc/anaconda3/envs/deeplearning/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# 2021-12-07 03:36:28,001:INFO:Evaluation do the evaluation 03subcl5-800-7-30-BI-full SMOTE KNeighborsClassifier
# 2021-12-07 03:36:28,048:INFO:Evaluation do the evaluation 03subcl5-800-7-30-BI-full SMOTE KNeighborsClassifier
# 2021-12-07 03:36:28,103:INFO:Evaluation do the evaluation 03subcl5-800-7-30-BI-full SMOTE KNeighborsClassifier
# /home/nmc/anaconda3/envs/deeplearning/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# 2021-12-07 03:36:28,152:INFO:Evaluation do the evaluation 03subcl5-800-7-30-BI-full SMOTE KNeighborsClassifier
# /home/nmc/anaconda3/envs/deeplearning/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# 2021-12-07 03:36:28,200:INFO:Evaluation do the evaluation 03subcl5-800-7-30-BI-full SMOTE KNeighborsClassifier
# 2021-12-07 03:36:28,255:INFO:Evaluation do the evaluation 03subcl5-800-7-30-BI-full SMOTE KNeighborsClassifier
# 2021-12-07 03:36:28,303:INFO:Evaluation do the evaluation 03subcl5-800-7-30-BI-full SMOTE KNeighborsClassifier
# 2021-12-07 03:36:28,350:INFO:Evaluation do the evaluation 03subcl5-800-7-30-BI-full SMOTE KNeighborsClassifier
# /home/nmc/anaconda3/envs/deeplearning/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# 2021-12-07 03:36:28,405:INFO:Evaluation do the evaluation 03subcl5-800-7-30-BI-full SMOTE KNeighborsClassifier
# 2021-12-07 03:36:28,465:INFO:Evaluation do the evaluation 03subcl5-800-7-30-BI-full SMOTE KNeighborsClassifier
# /home/nmc/anaconda3/envs/deeplearning/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# 2021-12-07 03:36:28,517:INFO:Evaluation do the evaluation 03subcl5-800-7-30-BI-full SMOTE KNeighborsClassifier
# 2021-12-07 03:36:28,577:INFO:Evaluation do the evaluation 03subcl5-800-7-30-BI-full SMOTE KNeighborsClassifier
# /home/nmc/anaconda3/envs/deeplearning/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# 2021-12-07 03:36:28,626:INFO:Evaluation do the evaluation 03subcl5-800-7-30-BI-full SMOTE KNeighborsClassifier
# 2021-12-07 03:36:28,674:INFO:Evaluation do the evaluation 03subcl5-800-7-30-BI-full SMOTE KNeighborsClassifier
# 2021-12-07 03:36:28,735:INFO:Evaluation do the evaluation 03subcl5-800-7-30-BI-full SMOTE KNeighborsClassifier
# 2021-12-07 03:36:28,785:INFO:Evaluation do the evaluation 03subcl5-800-7-30-BI-full SMOTE KNeighborsClassifier
# /home/nmc/anaconda3/envs/deeplearning/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# 2021-12-07 03:36:28,834:INFO:Evaluation do the evaluation 03subcl5-800-7-30-BI-full SMOTE KNeighborsClassifier
# 2021-12-07 03:36:28,890:INFO:Evaluation do the evaluation 03subcl5-800-7-30-BI-full SMOTE DecisionTreeClassifier
# /home/nmc/anaconda3/envs/deeplearning/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# 2021-12-07 03:36:28,934:INFO:Evaluation do the evaluation 03subcl5-800-7-30-BI-full SMOTE DecisionTreeClassifier
# 2021-12-07 03:36:28,976:INFO:Evaluation do the evaluation 03subcl5-800-7-30-BI-full SMOTE DecisionTreeClassifier
# 2021-12-07 03:36:29,019:INFO:Evaluation do the evaluation 03subcl5-800-7-30-BI-full SMOTE DecisionTreeClassifier
# /home/nmc/anaconda3/envs/deeplearning/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# 2021-12-07 03:36:29,068:INFO:Evaluation do the evaluation 03subcl5-800-7-30-BI-full SMOTE DecisionTreeClassifier
# 2021-12-07 03:36:29,108:INFO:Evaluation do the evaluation 03subcl5-800-7-30-BI-full SMOTE DecisionTreeClassifier
# /home/nmc/anaconda3/envs/deeplearning/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# 2021-12-07 03:36:29,151:INFO:Evaluation dumping to file eval_03subcl5-800-7-30-BI-full_SMOTE_127c04f07f1c239caab9bf547a671597.pickle
# /home/nmc/anaconda3/envs/deeplearning/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/nmc/anaconda3/envs/deeplearning/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/nmc/anaconda3/envs/deeplearning/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/nmc/anaconda3/envs/deeplearning/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/nmc/anaconda3/envs/deeplearning/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# 2021-12-07 03:36:30,226:INFO:Evaluation do the evaluation 03subcl5-800-7-30-BI-full SMOTE KNeighborsClassifier
# 2021-12-07 03:36:30,270:INFO:Evaluation do the evaluation 03subcl5-800-7-30-BI-full SMOTE KNeighborsClassifier
# 2021-12-07 03:36:30,316:INFO:Evaluation do the evaluation 03subcl5-800-7-30-BI-full SMOTE KNeighborsClassifier
# /home/nmc/anaconda3/envs/deeplearning/lib/python3.9/site-packages/smote_variants/_smote_variants.py:19736: RuntimeWarning: invalid value encountered in long_scalars
#   results['ppv'] = results['tp']/(results['tp'] + results['fp'])
# /home/nmc/anaconda3/envs/deeplearning/lib/python3.9/site-packages/smote_variants/_smote_variants.py:19753: RuntimeWarning: invalid value encountered in true_divide
#   results['mcc'] = mcc_num/np.sqrt(mcc_denom)
# /home/nmc/anaconda3/envs/deeplearning/lib/python3.9/site-packages/smote_variants/_smote_variants.py:19760: RuntimeWarning: invalid value encountered in long_scalars
#   results['ltp'] = results['tp']*np.log(results['tp']/(tp_fp*tp_fn))
# /home/nmc/anaconda3/envs/deeplearning/lib/python3.9/site-packages/smote_variants/_smote_variants.py:19761: RuntimeWarning: invalid value encountered in long_scalars
#   results['lfp'] = results['fp']*np.log(results['fp']/(tp_fp*tn_fp))
# 2021-12-07 03:36:30,339:INFO:Evaluation do the evaluation 03subcl5-800-7-30-BI-full SMOTE KNeighborsClassifier
# 2021-12-07 03:36:30,368:INFO:Evaluation do the evaluation 03subcl5-800-7-30-BI-full SMOTE KNeighborsClassifier
# 2021-12-07 03:36:30,386:INFO:Evaluation do the evaluation 03subcl5-800-7-30-BI-full SMOTE KNeighborsClassifier
# 2021-12-07 03:36:30,425:INFO:Evaluation do the evaluation 03subcl5-800-7-30-BI-full SMOTE KNeighborsClassifier
# 2021-12-07 03:36:30,432:INFO:Evaluation do the evaluation 03subcl5-800-7-30-BI-full SMOTE KNeighborsClassifier
# 2021-12-07 03:36:30,474:INFO:Evaluation do the evaluation 03subcl5-800-7-30-BI-full SMOTE KNeighborsClassifier
# 2021-12-07 03:36:30,486:INFO:Evaluation do the evaluation 03subcl5-800-7-30-BI-full SMOTE KNeighborsClassifier
# 2021-12-07 03:36:30,533:INFO:Evaluation do the evaluation 03subcl5-800-7-30-BI-full SMOTE KNeighborsClassifier
# 2021-12-07 03:36:30,536:INFO:Evaluation do the evaluation 03subcl5-800-7-30-BI-full SMOTE KNeighborsClassifier
# 2021-12-07 03:36:30,581:INFO:Evaluation do the evaluation 03subcl5-800-7-30-BI-full SMOTE KNeighborsClassifier
# 2021-12-07 03:36:30,583:INFO:Evaluation do the evaluation 03subcl5-800-7-30-BI-full SMOTE KNeighborsClassifier
# 2021-12-07 03:36:30,629:INFO:Evaluation do the evaluation 03subcl5-800-7-30-BI-full SMOTE KNeighborsClassifier
# 2021-12-07 03:36:30,635:INFO:Evaluation do the evaluation 03subcl5-800-7-30-BI-full SMOTE KNeighborsClassifier
# 2021-12-07 03:36:30,704:INFO:Evaluation do the evaluation 03subcl5-800-7-30-BI-full SMOTE KNeighborsClassifier
# 2021-12-07 03:36:30,708:INFO:Evaluation do the evaluation 03subcl5-800-7-30-BI-full SMOTE KNeighborsClassifier
# 2021-12-07 03:36:30,782:INFO:Evaluation do the evaluation 03subcl5-800-7-30-BI-full SMOTE KNeighborsClassifier
# 2021-12-07 03:36:30,785:INFO:Evaluation do the evaluation 03subcl5-800-7-30-BI-full SMOTE KNeighborsClassifier
# 2021-12-07 03:36:30,836:INFO:Evaluation do the evaluation 03subcl5-800-7-30-BI-full SMOTE KNeighborsClassifier
# 2021-12-07 03:36:30,845:INFO:Evaluation do the evaluation 03subcl5-800-7-30-BI-full SMOTE KNeighborsClassifier
# 2021-12-07 03:36:30,897:INFO:Evaluation do the evaluation 03subcl5-800-7-30-BI-full SMOTE KNeighborsClassifier
# 2021-12-07 03:36:30,904:INFO:Evaluation do the evaluation 03subcl5-800-7-30-BI-full SMOTE KNeighborsClassifier
# 2021-12-07 03:36:30,966:INFO:Evaluation do the evaluation 03subcl5-800-7-30-BI-full SMOTE KNeighborsClassifier
# 2021-12-07 03:36:30,972:INFO:Evaluation do the evaluation 03subcl5-800-7-30-BI-full SMOTE KNeighborsClassifier
# 2021-12-07 03:36:31,016:INFO:Evaluation do the evaluation 03subcl5-800-7-30-BI-full SMOTE KNeighborsClassifier
# 2021-12-07 03:36:31,028:INFO:Evaluation do the evaluation 03subcl5-800-7-30-BI-full SMOTE KNeighborsClassifier
# 2021-12-07 03:36:31,074:INFO:Evaluation do the evaluation 03subcl5-800-7-30-BI-full SMOTE KNeighborsClassifier
# 2021-12-07 03:36:31,078:INFO:Evaluation do the evaluation 03subcl5-800-7-30-BI-full SMOTE KNeighborsClassifier
# 2021-12-07 03:36:31,136:INFO:Evaluation do the evaluation 03subcl5-800-7-30-BI-full SMOTE KNeighborsClassifier
# 2021-12-07 03:36:31,141:INFO:Evaluation do the evaluation 03subcl5-800-7-30-BI-full SMOTE KNeighborsClassifier
# 2021-12-07 03:36:31,196:INFO:Evaluation do the evaluation 03subcl5-800-7-30-BI-full SMOTE KNeighborsClassifier
# 2021-12-07 03:36:31,203:INFO:Evaluation do the evaluation 03subcl5-800-7-30-BI-full SMOTE KNeighborsClassifier
# 2021-12-07 03:36:31,251:INFO:Evaluation do the evaluation 03subcl5-800-7-30-BI-full SMOTE DecisionTreeClassifier
# 2021-12-07 03:36:31,252:INFO:Evaluation do the evaluation 03subcl5-800-7-30-BI-full SMOTE KNeighborsClassifier
# 2021-12-07 03:36:31,295:INFO:Evaluation do the evaluation 03subcl5-800-7-30-BI-full SMOTE DecisionTreeClassifier
# 2021-12-07 03:36:31,300:INFO:Evaluation do the evaluation 03subcl5-800-7-30-BI-full SMOTE KNeighborsClassifier
# 2021-12-07 03:36:31,336:INFO:Evaluation do the evaluation 03subcl5-800-7-30-BI-full SMOTE DecisionTreeClassifier
# 2021-12-07 03:36:31,359:INFO:Evaluation do the evaluation 03subcl5-800-7-30-BI-full SMOTE DecisionTreeClassifier
# 2021-12-07 03:36:31,377:INFO:Evaluation do the evaluation 03subcl5-800-7-30-BI-full SMOTE DecisionTreeClassifier
# 2021-12-07 03:36:31,401:INFO:Evaluation do the evaluation 03subcl5-800-7-30-BI-full SMOTE DecisionTreeClassifier
# 2021-12-07 03:36:31,424:INFO:Evaluation do the evaluation 03subcl5-800-7-30-BI-full SMOTE DecisionTreeClassifier
# 2021-12-07 03:36:31,443:INFO:Evaluation do the evaluation 03subcl5-800-7-30-BI-full SMOTE DecisionTreeClassifier
# 2021-12-07 03:36:31,468:INFO:Evaluation do the evaluation 03subcl5-800-7-30-BI-full SMOTE DecisionTreeClassifier
# 2021-12-07 03:36:31,486:INFO:Evaluation do the evaluation 03subcl5-800-7-30-BI-full SMOTE DecisionTreeClassifier
# 2021-12-07 03:36:31,511:INFO:Evaluation dumping to file eval_03subcl5-800-7-30-BI-full_SMOTE_261f34ab6e7a8ad001d87ad2cc1f9c6e.pickle
# 2021-12-07 03:36:31,534:INFO:Evaluation do the evaluation 03subcl5-800-7-30-BI-full SMOTE DecisionTreeClassifier
# 2021-12-07 03:36:31,576:INFO:Evaluation do the evaluation 03subcl5-800-7-30-BI-full SMOTE DecisionTreeClassifier
# 2021-12-07 03:36:31,616:INFO:Evaluation dumping to file eval_03subcl5-800-7-30-BI-full_SMOTE_0591e5636ade0fc689952b4dab08374e.pickle
# 2021-12-07 03:36:31,623:INFO:concatenating the results
# 2021-12-07 03:36:31,847:INFO:aggregating the results

# %%
highest_auc_score= results['auc'].idxmax()
print(highest_auc_score)
# Out:
# 7

# %%
print(results.columns)
print("------------------------")
print(results)
# Out:
# Index(['db_name', 'classifier', 'sampler', 'auc', 'auc_mean', 'auc_std',
#        'brier', 'acc', 'f1', 'p_top20', 'gacc', 'runtime', 'db_size',
#        'db_n_attr', 'imbalanced_ratio', 'sampler_categories',
#        'classifier_parameters_auc', 'classifier_parameters_acc',
#        'classifier_parameters_gacc', 'classifier_parameters_f1',
#        'classifier_parameters_p_top20', 'classifier_parameters_brier',
#        'sampler_parameters_auc', 'sampler_parameters_acc',
#        'sampler_parameters_gacc', 'sampler_parameters_f1',
#        'sampler_parameters_p_top20', 'sampler_parameters_brier'],
#       dtype='object')
# ------------------------
#                       db_name              classifier            sampler  \
# 0   03subcl5-800-7-30-BI-full  CalibratedClassifierCV  Borderline_SMOTE1
# 1   03subcl5-800-7-30-BI-full  CalibratedClassifierCV  Borderline_SMOTE2
# 2   03subcl5-800-7-30-BI-full  CalibratedClassifierCV              SMOTE
# 3   03subcl5-800-7-30-BI-full  CalibratedClassifierCV          SMOTE_IPF
# 4   03subcl5-800-7-30-BI-full  DecisionTreeClassifier  Borderline_SMOTE1
# 5   03subcl5-800-7-30-BI-full  DecisionTreeClassifier  Borderline_SMOTE2
# 6   03subcl5-800-7-30-BI-full  DecisionTreeClassifier              SMOTE
# 7   03subcl5-800-7-30-BI-full  DecisionTreeClassifier          SMOTE_IPF
# 8   03subcl5-800-7-30-BI-full    KNeighborsClassifier  Borderline_SMOTE1
# 9   03subcl5-800-7-30-BI-full    KNeighborsClassifier  Borderline_SMOTE2
# 10  03subcl5-800-7-30-BI-full    KNeighborsClassifier              SMOTE
# 11  03subcl5-800-7-30-BI-full    KNeighborsClassifier          SMOTE_IPF
# 12  03subcl5-800-7-30-BI-full    MLPClassifierWrapper  Borderline_SMOTE1
# 13  03subcl5-800-7-30-BI-full    MLPClassifierWrapper  Borderline_SMOTE2
# 14  03subcl5-800-7-30-BI-full    MLPClassifierWrapper              SMOTE
# 15  03subcl5-800-7-30-BI-full    MLPClassifierWrapper          SMOTE_IPF
#
#          auc  auc_mean   auc_std     brier       acc        f1   p_top20  ...  \
# 0   0.532448  0.551048  0.058660  0.113149  0.875000  0.245186  0.139583  ...
# 1   0.532086  0.537500  0.047265  0.113149  0.875000  0.243181  0.137500  ...
# 2   0.511278  0.527857  0.064601  0.113149  0.875000  0.227015  0.156250  ...
# 3   0.513556  0.534060  0.085987  0.113149  0.875000  0.225564  0.147917  ...
# 4   0.887360  0.889464  0.023932  0.080000  0.913750  0.664506  0.497917  ...
# 5   0.877779  0.875964  0.029373  0.085719  0.907083  0.640902  0.483333  ...
# 6   0.887669  0.891190  0.029410  0.081112  0.917083  0.675367  0.500000  ...
# 7   0.891944  0.888845  0.028471  0.080465  0.918750  0.681892  0.500000  ...
# 8   0.873706  0.875226  0.045291  0.074305  0.902500  0.569395  0.452083  ...
# 9   0.875070  0.876405  0.038099  0.077484  0.896250  0.554562  0.447917  ...
# 10  0.883675  0.884774  0.038035  0.072938  0.905833  0.586331  0.462500  ...
# 11  0.888644  0.889107  0.035472  0.072865  0.904167  0.580952  0.458333  ...
# 12  0.736174  0.719881  0.143695  0.124836  0.875000  0.320675  0.266667  ...
# 13  0.729790  0.723929  0.118231  0.118719  0.875000  0.315089  0.254167  ...
# 14  0.760479  0.742821  0.114486  0.124787  0.875000  0.328125  0.287500  ...
# 15  0.746879  0.744583  0.136328  0.126099  0.875000  0.326230  0.306250  ...
#
#                            classifier_parameters_gacc  \
# 0   {'base_estimator__C': 10.0, 'base_estimator__c...
# 1   {'base_estimator__C': 10.0, 'base_estimator__c...
# 2   {'base_estimator__C': 1.0, 'base_estimator__cl...
# 3   {'base_estimator__C': 10.0, 'base_estimator__c...
# 4   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...
# 5   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...
# 6   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...
# 7   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...
# 8   {'algorithm': 'auto', 'leaf_size': 30, 'metric...
# 9   {'algorithm': 'auto', 'leaf_size': 30, 'metric...
# 10  {'algorithm': 'auto', 'leaf_size': 30, 'metric...
# 11  {'algorithm': 'auto', 'leaf_size': 30, 'metric...
# 12  {'activation': 'relu', 'hidden_layer_fraction'...
# 13  {'activation': 'relu', 'hidden_layer_fraction'...
# 14  {'activation': 'relu', 'hidden_layer_fraction'...
# 15  {'activation': 'relu', 'hidden_layer_fraction'...
#
#                              classifier_parameters_f1  \
# 0   {'base_estimator__C': 1.0, 'base_estimator__cl...
# 1   {'base_estimator__C': 1.0, 'base_estimator__cl...
# 2   {'base_estimator__C': 1.0, 'base_estimator__cl...
# 3   {'base_estimator__C': 1.0, 'base_estimator__cl...
# 4   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...
# 5   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...
# 6   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...
# 7   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...
# 8   {'algorithm': 'auto', 'leaf_size': 30, 'metric...
# 9   {'algorithm': 'auto', 'leaf_size': 30, 'metric...
# 10  {'algorithm': 'auto', 'leaf_size': 30, 'metric...
# 11  {'algorithm': 'auto', 'leaf_size': 30, 'metric...
# 12  {'activation': 'relu', 'hidden_layer_fraction'...
# 13  {'activation': 'relu', 'hidden_layer_fraction'...
# 14  {'activation': 'relu', 'hidden_layer_fraction'...
# 15  {'activation': 'relu', 'hidden_layer_fraction'...
#
#                         classifier_parameters_p_top20  \
# 0   {'base_estimator__C': 10.0, 'base_estimator__c...
# 1   {'base_estimator__C': 10.0, 'base_estimator__c...
# 2   {'base_estimator__C': 1.0, 'base_estimator__cl...
# 3   {'base_estimator__C': 10.0, 'base_estimator__c...
# 4   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...
# 5   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...
# 6   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...
# 7   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...
# 8   {'algorithm': 'auto', 'leaf_size': 30, 'metric...
# 9   {'algorithm': 'auto', 'leaf_size': 30, 'metric...
# 10  {'algorithm': 'auto', 'leaf_size': 30, 'metric...
# 11  {'algorithm': 'auto', 'leaf_size': 30, 'metric...
# 12  {'activation': 'relu', 'hidden_layer_fraction'...
# 13  {'activation': 'relu', 'hidden_layer_fraction'...
# 14  {'activation': 'relu', 'hidden_layer_fraction'...
# 15  {'activation': 'relu', 'hidden_layer_fraction'...
#
#                           classifier_parameters_brier  \
# 0   {'base_estimator__C': 1.0, 'base_estimator__cl...
# 1   {'base_estimator__C': 10.0, 'base_estimator__c...
# 2   {'base_estimator__C': 1.0, 'base_estimator__cl...
# 3   {'base_estimator__C': 1.0, 'base_estimator__cl...
# 4   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...
# 5   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...
# 6   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...
# 7   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...
# 8   {'algorithm': 'auto', 'leaf_size': 30, 'metric...
# 9   {'algorithm': 'auto', 'leaf_size': 30, 'metric...
# 10  {'algorithm': 'auto', 'leaf_size': 30, 'metric...
# 11  {'algorithm': 'auto', 'leaf_size': 30, 'metric...
# 12  {'activation': 'logistic', 'hidden_layer_fract...
# 13  {'activation': 'logistic', 'hidden_layer_fract...
# 14  {'activation': 'logistic', 'hidden_layer_fract...
# 15  {'activation': 'logistic', 'hidden_layer_fract...
#
#                                sampler_parameters_auc  \
# 0   {'k_neighbors': 7, 'n_neighbors': 5, 'proporti...
# 1   {'k_neighbors': 3, 'n_neighbors': 5, 'proporti...
# 2   {'n_neighbors': 5, 'proportion': 1.0, 'random_...
# 3   {'classifier': DecisionTreeClassifier(random_s...
# 4   {'k_neighbors': 3, 'n_neighbors': 5, 'proporti...
# 5   {'k_neighbors': 7, 'n_neighbors': 7, 'proporti...
# 6   {'n_neighbors': 5, 'proportion': 1.0, 'random_...
# 7   {'classifier': DecisionTreeClassifier(random_s...
# 8   {'k_neighbors': 7, 'n_neighbors': 5, 'proporti...
# 9   {'k_neighbors': 7, 'n_neighbors': 5, 'proporti...
# 10  {'n_neighbors': 7, 'proportion': 2.0, 'random_...
# 11  {'classifier': DecisionTreeClassifier(random_s...
# 12  {'k_neighbors': 3, 'n_neighbors': 3, 'proporti...
# 13  {'k_neighbors': 5, 'n_neighbors': 5, 'proporti...
# 14  {'n_neighbors': 7, 'proportion': 2.0, 'random_...
# 15  {'classifier': DecisionTreeClassifier(random_s...
#
#                                sampler_parameters_acc  \
# 0   {'k_neighbors': 5, 'n_neighbors': 3, 'proporti...
# 1   {'k_neighbors': 7, 'n_neighbors': 3, 'proporti...
# 2   {'n_neighbors': 3, 'proportion': 0.1, 'random_...
# 3   {'classifier': DecisionTreeClassifier(random_s...
# 4   {'k_neighbors': 3, 'n_neighbors': 5, 'proporti...
# 5   {'k_neighbors': 3, 'n_neighbors': 3, 'proporti...
# 6   {'n_neighbors': 3, 'proportion': 0.1, 'random_...
# 7   {'classifier': DecisionTreeClassifier(random_s...
# 8   {'k_neighbors': 7, 'n_neighbors': 5, 'proporti...
# 9   {'k_neighbors': 3, 'n_neighbors': 5, 'proporti...
# 10  {'n_neighbors': 7, 'proportion': 0.1, 'random_...
# 11  {'classifier': DecisionTreeClassifier(random_s...
# 12  {'k_neighbors': 3, 'n_neighbors': 5, 'proporti...
# 13  {'k_neighbors': 7, 'n_neighbors': 3, 'proporti...
# 14  {'n_neighbors': 5, 'proportion': 0.5, 'random_...
# 15  {'classifier': DecisionTreeClassifier(random_s...
#
#                               sampler_parameters_gacc  \
# 0   {'k_neighbors': 5, 'n_neighbors': 7, 'proporti...
# 1   {'k_neighbors': 3, 'n_neighbors': 5, 'proporti...
# 2   {'n_neighbors': 7, 'proportion': 1.0, 'random_...
# 3   {'classifier': DecisionTreeClassifier(random_s...
# 4   {'k_neighbors': 5, 'n_neighbors': 7, 'proporti...
# 5   {'k_neighbors': 7, 'n_neighbors': 5, 'proporti...
# 6   {'n_neighbors': 7, 'proportion': 1.0, 'random_...
# 7   {'classifier': DecisionTreeClassifier(random_s...
# 8   {'k_neighbors': 5, 'n_neighbors': 7, 'proporti...
# 9   {'k_neighbors': 7, 'n_neighbors': 7, 'proporti...
# 10  {'n_neighbors': 3, 'proportion': 1.0, 'random_...
# 11  {'classifier': DecisionTreeClassifier(random_s...
# 12  {'k_neighbors': 3, 'n_neighbors': 3, 'proporti...
# 13  {'k_neighbors': 7, 'n_neighbors': 3, 'proporti...
# 14  {'n_neighbors': 5, 'proportion': 1.0, 'random_...
# 15  {'classifier': DecisionTreeClassifier(random_s...
#
#                                 sampler_parameters_f1  \
# 0   {'k_neighbors': 5, 'n_neighbors': 5, 'proporti...
# 1   {'k_neighbors': 3, 'n_neighbors': 5, 'proporti...
# 2   {'n_neighbors': 7, 'proportion': 1.5, 'random_...
# 3   {'classifier': DecisionTreeClassifier(random_s...
# 4   {'k_neighbors': 3, 'n_neighbors': 5, 'proporti...
# 5   {'k_neighbors': 3, 'n_neighbors': 3, 'proporti...
# 6   {'n_neighbors': 3, 'proportion': 0.1, 'random_...
# 7   {'classifier': DecisionTreeClassifier(random_s...
# 8   {'k_neighbors': 3, 'n_neighbors': 5, 'proporti...
# 9   {'k_neighbors': 3, 'n_neighbors': 5, 'proporti...
# 10  {'n_neighbors': 3, 'proportion': 0.1, 'random_...
# 11  {'classifier': DecisionTreeClassifier(random_s...
# 12  {'k_neighbors': 3, 'n_neighbors': 3, 'proporti...
# 13  {'k_neighbors': 7, 'n_neighbors': 3, 'proporti...
# 14  {'n_neighbors': 5, 'proportion': 1.0, 'random_...
# 15  {'classifier': DecisionTreeClassifier(random_s...
#
#                            sampler_parameters_p_top20  \
# 0   {'k_neighbors': 3, 'n_neighbors': 5, 'proporti...
# 1   {'k_neighbors': 3, 'n_neighbors': 3, 'proporti...
# 2   {'n_neighbors': 5, 'proportion': 0.75, 'random...
# 3   {'classifier': DecisionTreeClassifier(random_s...
# 4   {'k_neighbors': 3, 'n_neighbors': 5, 'proporti...
# 5   {'k_neighbors': 7, 'n_neighbors': 3, 'proporti...
# 6   {'n_neighbors': 7, 'proportion': 1.5, 'random_...
# 7   {'classifier': DecisionTreeClassifier(random_s...
# 8   {'k_neighbors': 3, 'n_neighbors': 5, 'proporti...
# 9   {'k_neighbors': 3, 'n_neighbors': 5, 'proporti...
# 10  {'n_neighbors': 3, 'proportion': 2.0, 'random_...
# 11  {'classifier': DecisionTreeClassifier(random_s...
# 12  {'k_neighbors': 3, 'n_neighbors': 3, 'proporti...
# 13  {'k_neighbors': 3, 'n_neighbors': 7, 'proporti...
# 14  {'n_neighbors': 7, 'proportion': 2.0, 'random_...
# 15  {'classifier': DecisionTreeClassifier(random_s...
#
#                              sampler_parameters_brier
# 0   {'k_neighbors': 3, 'n_neighbors': 5, 'proporti...
# 1   {'k_neighbors': 7, 'n_neighbors': 7, 'proporti...
# 2   {'n_neighbors': 5, 'proportion': 0.1, 'random_...
# 3   {'classifier': DecisionTreeClassifier(random_s...
# 4   {'k_neighbors': 3, 'n_neighbors': 5, 'proporti...
# 5   {'k_neighbors': 7, 'n_neighbors': 7, 'proporti...
# 6   {'n_neighbors': 3, 'proportion': 2.0, 'random_...
# 7   {'classifier': DecisionTreeClassifier(random_s...
# 8   {'k_neighbors': 3, 'n_neighbors': 3, 'proporti...
# 9   {'k_neighbors': 3, 'n_neighbors': 3, 'proporti...
# 10  {'n_neighbors': 7, 'proportion': 0.1, 'random_...
# 11  {'classifier': DecisionTreeClassifier(random_s...
# 12  {'k_neighbors': 3, 'n_neighbors': 3, 'proporti...
# 13  {'k_neighbors': 7, 'n_neighbors': 3, 'proporti...
# 14  {'n_neighbors': 7, 'proportion': 1.0, 'random_...
# 15  {'classifier': DecisionTreeClassifier(random_s...
#
# [16 rows x 28 columns]

# %%
print(results[['db_name', 'classifier', 'sampler', 'auc']].to_html('sub-cluster.html'))
# Out:
# None
